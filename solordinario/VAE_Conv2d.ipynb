# %%
# %matplotlib inline
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
# Espace latent 2 dimensions

latent_dims = 2
num_epochs = 500
batch_size = 1
capacity = 16
learning_rate = 1e-3
variational_beta = 0.01
use_gpu = True



# # 10-d Espace latent en 10 dimensions, qui correspond à un Autoencoder simple (à comparer avec le VAE 
# et un espace latent de 2 dimensions)
# latent_dims = 10
# num_epochs = 100
# batch_size = 128
# capacity = 64
# learning_rate = 1e-3
# variational_beta = 1
# use_gpu = True

# %% [markdown]
# # Chargement des données

# %%
import os
import descriptors
import numpy as np

dict_r = np.load('data_dict.npy', allow_pickle=True).item()

train_db = np.zeros([len(dict_r['env']),2,750])
i = 0
for sample in dict_r['env']:
    train_db[i,:,:] = sample
    i+=1
    
train_dataset =  torch.utils.data.TensorDataset(torch.from_numpy(train_db))
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True)

test_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True)

# %% [markdown]
# # Defintion du VAE
#
# Kernel Size = 4 papier qui explique pourquoi: https://distill.pub/2016/deconv-checkerboard/

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=c, kernel_size=1, stride=1, padding=0) # out: c, 2, 750
        self.conv2 = nn.Conv2d(in_channels=c, out_channels=c*2, kernel_size=1, stride=1, padding=0) # out: c*2, 2, 750
        self.fc_mu = nn.Linear(in_features=2*c*2*750, out_features=latent_dims)
        self.fc_logvar = nn.Linear(in_features=2*c*2*750, out_features=latent_dims)
            
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=2*c*2*750)
        self.conv2 = nn.ConvTranspose2d(in_channels=c*2, out_channels=c, kernel_size=1, stride=1, padding=0)
        self.conv1 = nn.ConvTranspose2d(in_channels=c, out_channels=1, kernel_size=1, stride=1, padding=0)
            
    def forward(self, x):
        x = self.fc(x)
        x = x.view(x.size(0), capacity*2, 2,750) # unflatten batch of feature vectors to a batch of multi-channel feature maps
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv1(x)) # last layer before output is sigmoid, since we are using BCE as reconstruction loss
        return x
    
class VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            # the reparameterization trick
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu
    
def vae_loss(recon_x, x, mu, logvar):
    # recon_x is the probability of a multivariate Bernoulli distribution p.
    # -log(p(x)) is then the pixel-wise binary cross-entropy.
    # Averaging or not averaging the binary cross-entropy over all pixels here
    # is a subtle detail with big effect on training, since it changes the weight
    # we need to pick for the other loss term by several orders of magnitude.
    # Not averaging is the direct implementation of the negative log likelihood,
    # but averaging makes the weight of the other loss term independent of the image resolution.
    recon_loss = F.binary_cross_entropy(recon_x.view(-1, batch_size*2*750), x.view(-1, batch_size*2*750), reduction='sum')
    
    # KL-divergence between the prior distribution over latent vectors
    # (the one we are going to sample from when generating new images)
    # and the distribution estimated by the generator for the given image.
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + variational_beta * kldivergence
    
    
vae = VariationalAutoencoder()

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
vae = vae.to(device)

num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 337125
# C:\Users\gabri\Anaconda3\lib\site-packages\torch\cuda\__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 9010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# # Entrainement

# %%
optimizer = torch.optim.Adam(params=vae.parameters(), lr=learning_rate, weight_decay=1e-5)

# set to training mode
vae.train()

train_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    
    for image_batch in train_loader:
        
        
        #image_batch = image_batch.to(device)
        image_batch = torch.DoubleTensor(image_batch[0])
        Max_image_batch = torch.max(image_batch)
        image_batch = image_batch.view(batch_size,1,2,750)/Max_image_batch
        
        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch.float())
        
        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch.float(), latent_mu, latent_logvar)
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        # one step of the optmizer (using the gradients from backpropagation)
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()
        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
# Out:
# Training ...
# Epoch [1 / 500] average reconstruction error: 404.549518
# Epoch [2 / 500] average reconstruction error: 122.867054
# Epoch [3 / 500] average reconstruction error: 118.124844
# Epoch [4 / 500] average reconstruction error: 113.701434
# Epoch [5 / 500] average reconstruction error: 110.018217
# Epoch [6 / 500] average reconstruction error: 110.624945
# Epoch [7 / 500] average reconstruction error: 105.707044
# Epoch [8 / 500] average reconstruction error: 104.504907
# Epoch [9 / 500] average reconstruction error: 103.104799
# Epoch [10 / 500] average reconstruction error: 103.666533
# Epoch [11 / 500] average reconstruction error: 102.759673
# Epoch [12 / 500] average reconstruction error: 102.438207
# Epoch [13 / 500] average reconstruction error: 102.153749
# Epoch [14 / 500] average reconstruction error: 100.521378
# Epoch [15 / 500] average reconstruction error: 101.872150
# Epoch [16 / 500] average reconstruction error: 101.845234
# Epoch [17 / 500] average reconstruction error: 100.141645
# Epoch [18 / 500] average reconstruction error: 99.921781
# Epoch [19 / 500] average reconstruction error: 99.979565
# Epoch [20 / 500] average reconstruction error: 100.114375
# Epoch [21 / 500] average reconstruction error: 99.910734
# Epoch [22 / 500] average reconstruction error: 99.798972
# Epoch [23 / 500] average reconstruction error: 98.875616
# Epoch [24 / 500] average reconstruction error: 99.738033
# Epoch [25 / 500] average reconstruction error: 98.544034
# Epoch [26 / 500] average reconstruction error: 98.281574
# Epoch [27 / 500] average reconstruction error: 99.655624
# Epoch [28 / 500] average reconstruction error: 98.683140
# Epoch [29 / 500] average reconstruction error: 98.064178
# Epoch [30 / 500] average reconstruction error: 99.664385
# Epoch [31 / 500] average reconstruction error: 99.031487
# Epoch [32 / 500] average reconstruction error: 98.049688
# Epoch [33 / 500] average reconstruction error: 97.611052
# Epoch [34 / 500] average reconstruction error: 97.322960
# Epoch [35 / 500] average reconstruction error: 97.125154
# Epoch [36 / 500] average reconstruction error: 97.277204
# Epoch [37 / 500] average reconstruction error: 97.602243
# Epoch [38 / 500] average reconstruction error: 96.903593
# Epoch [39 / 500] average reconstruction error: 96.839132
# Epoch [40 / 500] average reconstruction error: 96.830998
# Epoch [41 / 500] average reconstruction error: 96.881389
# Epoch [42 / 500] average reconstruction error: 96.413129
# Epoch [43 / 500] average reconstruction error: 96.540316
# Epoch [44 / 500] average reconstruction error: 96.492597
# Epoch [45 / 500] average reconstruction error: 96.408926
# Epoch [46 / 500] average reconstruction error: 96.392812
# Epoch [47 / 500] average reconstruction error: 96.478001
# Epoch [48 / 500] average reconstruction error: 96.288334
# Epoch [49 / 500] average reconstruction error: 96.024568
# Epoch [50 / 500] average reconstruction error: 95.720231
# Epoch [51 / 500] average reconstruction error: 95.696992
# Epoch [52 / 500] average reconstruction error: 96.020272
# Epoch [53 / 500] average reconstruction error: 95.984607
# Epoch [54 / 500] average reconstruction error: 96.760102
# Epoch [55 / 500] average reconstruction error: 96.347637
# Epoch [56 / 500] average reconstruction error: 95.812564
# Epoch [57 / 500] average reconstruction error: 95.731623
# Epoch [58 / 500] average reconstruction error: 95.855892
# Epoch [59 / 500] average reconstruction error: 95.857365
# Epoch [60 / 500] average reconstruction error: 96.006525
# Epoch [61 / 500] average reconstruction error: 95.779960
# Epoch [62 / 500] average reconstruction error: 95.847898
# Epoch [63 / 500] average reconstruction error: 96.378432
# Epoch [64 / 500] average reconstruction error: 95.851196
# Epoch [65 / 500] average reconstruction error: 95.898269
# Epoch [66 / 500] average reconstruction error: 95.939852
# Epoch [67 / 500] average reconstruction error: 95.396470
# Epoch [68 / 500] average reconstruction error: 95.549243
# Epoch [69 / 500] average reconstruction error: 95.304893
# Epoch [70 / 500] average reconstruction error: 95.480503
# Epoch [71 / 500] average reconstruction error: 95.153708
# Epoch [72 / 500] average reconstruction error: 94.916030
# Epoch [73 / 500] average reconstruction error: 95.052734
# Epoch [74 / 500] average reconstruction error: 95.184604
# Epoch [75 / 500] average reconstruction error: 95.560579
# Epoch [76 / 500] average reconstruction error: 95.060648
# Epoch [77 / 500] average reconstruction error: 95.722764
# Epoch [78 / 500] average reconstruction error: 94.932299
# Epoch [79 / 500] average reconstruction error: 95.123506
# Epoch [80 / 500] average reconstruction error: 95.108920
# Epoch [81 / 500] average reconstruction error: 94.851568
# Epoch [82 / 500] average reconstruction error: 95.465308
# Epoch [83 / 500] average reconstruction error: 94.907205
# Epoch [84 / 500] average reconstruction error: 94.845480
# Epoch [85 / 500] average reconstruction error: 94.707001
# Epoch [86 / 500] average reconstruction error: 94.715789
# Epoch [87 / 500] average reconstruction error: 96.047403
# Epoch [88 / 500] average reconstruction error: 95.112237
# Epoch [89 / 500] average reconstruction error: 95.224888
# Epoch [90 / 500] average reconstruction error: 94.963378
# Epoch [91 / 500] average reconstruction error: 95.313194
# Epoch [92 / 500] average reconstruction error: 94.776414
# Epoch [93 / 500] average reconstruction error: 94.912118
# Epoch [94 / 500] average reconstruction error: 94.859004
# Epoch [95 / 500] average reconstruction error: 94.581891
# Epoch [96 / 500] average reconstruction error: 94.743747
# Epoch [97 / 500] average reconstruction error: 94.580703
# Epoch [98 / 500] average reconstruction error: 94.922457
# Epoch [99 / 500] average reconstruction error: 94.554983
# Epoch [100 / 500] average reconstruction error: 94.733827
# Epoch [101 / 500] average reconstruction error: 94.609015
# Epoch [102 / 500] average reconstruction error: 94.753462
# Epoch [103 / 500] average reconstruction error: 94.833239
# Epoch [104 / 500] average reconstruction error: 94.869279
# Epoch [105 / 500] average reconstruction error: 94.872442
# Epoch [106 / 500] average reconstruction error: 94.542068
# Epoch [107 / 500] average reconstruction error: 94.444402
# Epoch [108 / 500] average reconstruction error: 94.740796
# Epoch [109 / 500] average reconstruction error: 94.562612
# Epoch [110 / 500] average reconstruction error: 94.458755
# Epoch [111 / 500] average reconstruction error: 95.286269
# Epoch [112 / 500] average reconstruction error: 94.707989
# Epoch [113 / 500] average reconstruction error: 94.468482
# Epoch [114 / 500] average reconstruction error: 94.484234
# Epoch [115 / 500] average reconstruction error: 94.523646
# Epoch [116 / 500] average reconstruction error: 94.469603
# Epoch [117 / 500] average reconstruction error: 94.359673
# Epoch [118 / 500] average reconstruction error: 94.450285
# Epoch [119 / 500] average reconstruction error: 94.196232
# Epoch [120 / 500] average reconstruction error: 94.788022
# Epoch [121 / 500] average reconstruction error: 94.647568
# Epoch [122 / 500] average reconstruction error: 94.480906
# Epoch [123 / 500] average reconstruction error: 95.018552
# Epoch [124 / 500] average reconstruction error: 94.771685
# Epoch [125 / 500] average reconstruction error: 94.219235
# Epoch [126 / 500] average reconstruction error: 94.331564
# Epoch [127 / 500] average reconstruction error: 94.336909
# Epoch [128 / 500] average reconstruction error: 94.301178
# Epoch [129 / 500] average reconstruction error: 94.309586
# Epoch [130 / 500] average reconstruction error: 94.332116
# Epoch [131 / 500] average reconstruction error: 94.682156
# Epoch [132 / 500] average reconstruction error: 94.701643
# Epoch [133 / 500] average reconstruction error: 94.352328
# Epoch [134 / 500] average reconstruction error: 94.185095
# Epoch [135 / 500] average reconstruction error: 94.133692
# Epoch [136 / 500] average reconstruction error: 94.479943
# Epoch [137 / 500] average reconstruction error: 95.009971
# Epoch [138 / 500] average reconstruction error: 94.173481
# Epoch [139 / 500] average reconstruction error: 93.964071
# Epoch [140 / 500] average reconstruction error: 94.137662
# Epoch [141 / 500] average reconstruction error: 94.172592
# Epoch [142 / 500] average reconstruction error: 94.239880
# Epoch [143 / 500] average reconstruction error: 94.035437
# Epoch [144 / 500] average reconstruction error: 94.490708
# Epoch [145 / 500] average reconstruction error: 94.712864
# Epoch [146 / 500] average reconstruction error: 94.372504
# Epoch [147 / 500] average reconstruction error: 94.032341
# Epoch [148 / 500] average reconstruction error: 94.313625
# Epoch [149 / 500] average reconstruction error: 93.941580
# Epoch [150 / 500] average reconstruction error: 94.020560
# Epoch [151 / 500] average reconstruction error: 94.132512
# Epoch [152 / 500] average reconstruction error: 94.059065
# Epoch [153 / 500] average reconstruction error: 94.431606
# Epoch [154 / 500] average reconstruction error: 94.040832
# Epoch [155 / 500] average reconstruction error: 94.214399
# Epoch [156 / 500] average reconstruction error: 94.037260
# Epoch [157 / 500] average reconstruction error: 93.831733
# Epoch [158 / 500] average reconstruction error: 93.948414
# Epoch [159 / 500] average reconstruction error: 94.157797
# Epoch [160 / 500] average reconstruction error: 93.882286
# Epoch [161 / 500] average reconstruction error: 93.908242
# Epoch [162 / 500] average reconstruction error: 93.945401
# Epoch [163 / 500] average reconstruction error: 94.257217
# Epoch [164 / 500] average reconstruction error: 94.193244
# Epoch [165 / 500] average reconstruction error: 94.526439
# Epoch [166 / 500] average reconstruction error: 94.624243
# Epoch [167 / 500] average reconstruction error: 93.783228
# Epoch [168 / 500] average reconstruction error: 93.937136
# Epoch [169 / 500] average reconstruction error: 93.857256
# Epoch [170 / 500] average reconstruction error: 94.219464
# Epoch [171 / 500] average reconstruction error: 94.399135
# Epoch [172 / 500] average reconstruction error: 94.269834
# Epoch [173 / 500] average reconstruction error: 93.772038
# Epoch [174 / 500] average reconstruction error: 93.918032
# Epoch [175 / 500] average reconstruction error: 93.866326
# Epoch [176 / 500] average reconstruction error: 94.421796
# Epoch [177 / 500] average reconstruction error: 93.983497
# Epoch [178 / 500] average reconstruction error: 94.027590
# Epoch [179 / 500] average reconstruction error: 94.091736
# Epoch [180 / 500] average reconstruction error: 93.889174
# Epoch [181 / 500] average reconstruction error: 94.184498
# Epoch [182 / 500] average reconstruction error: 94.103613
# Epoch [183 / 500] average reconstruction error: 93.871938
# Epoch [184 / 500] average reconstruction error: 93.818945
# Epoch [185 / 500] average reconstruction error: 93.678383
# Epoch [186 / 500] average reconstruction error: 93.937477
# Epoch [187 / 500] average reconstruction error: 94.048430
# Epoch [188 / 500] average reconstruction error: 94.112939
# Epoch [189 / 500] average reconstruction error: 93.716678
# Epoch [190 / 500] average reconstruction error: 93.656362
# Epoch [191 / 500] average reconstruction error: 94.478078
# Epoch [192 / 500] average reconstruction error: 94.525688
# Epoch [193 / 500] average reconstruction error: 93.831899
# Epoch [194 / 500] average reconstruction error: 94.012131
# Epoch [195 / 500] average reconstruction error: 93.873121
# Epoch [196 / 500] average reconstruction error: 93.691068
# Epoch [197 / 500] average reconstruction error: 93.855517
# Epoch [198 / 500] average reconstruction error: 93.662394
# Epoch [199 / 500] average reconstruction error: 93.857512
# Epoch [200 / 500] average reconstruction error: 93.646130
# Epoch [201 / 500] average reconstruction error: 93.586988
# Epoch [202 / 500] average reconstruction error: 93.779790
# Epoch [203 / 500] average reconstruction error: 93.675761
# Epoch [204 / 500] average reconstruction error: 93.739271
# Epoch [205 / 500] average reconstruction error: 93.924720
# Epoch [206 / 500] average reconstruction error: 93.819553
# Epoch [207 / 500] average reconstruction error: 93.768174
# Epoch [208 / 500] average reconstruction error: 94.148949
# Epoch [209 / 500] average reconstruction error: 94.103175
# Epoch [210 / 500] average reconstruction error: 93.757063
# Epoch [211 / 500] average reconstruction error: 93.524364
# Epoch [212 / 500] average reconstruction error: 93.930840
# Epoch [213 / 500] average reconstruction error: 93.777348
# Epoch [214 / 500] average reconstruction error: 93.638149
# Epoch [215 / 500] average reconstruction error: 93.780851
# Epoch [216 / 500] average reconstruction error: 93.742854
# Epoch [217 / 500] average reconstruction error: 93.794849
# Epoch [218 / 500] average reconstruction error: 93.995421
# Epoch [219 / 500] average reconstruction error: 93.805530
# Epoch [220 / 500] average reconstruction error: 94.460419
# Epoch [221 / 500] average reconstruction error: 93.689197
# Epoch [222 / 500] average reconstruction error: 93.756143
# Epoch [223 / 500] average reconstruction error: 93.581552
# Epoch [224 / 500] average reconstruction error: 93.593208
# Epoch [225 / 500] average reconstruction error: 93.466373
# Epoch [226 / 500] average reconstruction error: 93.572088
# Epoch [227 / 500] average reconstruction error: 93.750476
# Epoch [228 / 500] average reconstruction error: 93.820775
# Epoch [229 / 500] average reconstruction error: 94.068788
# Epoch [230 / 500] average reconstruction error: 94.163874
# Epoch [231 / 500] average reconstruction error: 93.463648
# Epoch [232 / 500] average reconstruction error: 93.481540
# Epoch [233 / 500] average reconstruction error: 94.033738
# Epoch [234 / 500] average reconstruction error: 93.813306
# Epoch [235 / 500] average reconstruction error: 93.576380
# Epoch [236 / 500] average reconstruction error: 93.548761
# Epoch [237 / 500] average reconstruction error: 93.750236
# Epoch [238 / 500] average reconstruction error: 93.839727
# Epoch [239 / 500] average reconstruction error: 93.659371
# Epoch [240 / 500] average reconstruction error: 93.461495
# Epoch [241 / 500] average reconstruction error: 93.671743
# Epoch [242 / 500] average reconstruction error: 93.583079
# Epoch [243 / 500] average reconstruction error: 93.719517
# Epoch [244 / 500] average reconstruction error: 94.013676
# Epoch [245 / 500] average reconstruction error: 94.431024
# Epoch [246 / 500] average reconstruction error: 93.651031
# Epoch [247 / 500] average reconstruction error: 93.411643
# Epoch [248 / 500] average reconstruction error: 93.539172
# Epoch [249 / 500] average reconstruction error: 93.575170
# Epoch [250 / 500] average reconstruction error: 93.466826
# Epoch [251 / 500] average reconstruction error: 93.469938
# Epoch [252 / 500] average reconstruction error: 93.486325
# Epoch [253 / 500] average reconstruction error: 93.849417
# Epoch [254 / 500] average reconstruction error: 93.770357
# Epoch [255 / 500] average reconstruction error: 94.002957
# Epoch [256 / 500] average reconstruction error: 93.567435
# Epoch [257 / 500] average reconstruction error: 94.171306
# Epoch [258 / 500] average reconstruction error: 94.138961
# Epoch [259 / 500] average reconstruction error: 93.521685
# Epoch [260 / 500] average reconstruction error: 93.448745
# Epoch [261 / 500] average reconstruction error: 93.498565
# Epoch [262 / 500] average reconstruction error: 93.482047
# Epoch [263 / 500] average reconstruction error: 93.498613
# Epoch [264 / 500] average reconstruction error: 93.411969
# Epoch [265 / 500] average reconstruction error: 93.873724
# Epoch [266 / 500] average reconstruction error: 93.560645
# Epoch [267 / 500] average reconstruction error: 93.545313
# Epoch [268 / 500] average reconstruction error: 93.484072
# Epoch [269 / 500] average reconstruction error: 93.487584
# Epoch [270 / 500] average reconstruction error: 93.564413
# Epoch [271 / 500] average reconstruction error: 93.772087
# Epoch [272 / 500] average reconstruction error: 93.711891
# Epoch [273 / 500] average reconstruction error: 93.705179
# Epoch [274 / 500] average reconstruction error: 93.667412
# Epoch [275 / 500] average reconstruction error: 93.433595
# Epoch [276 / 500] average reconstruction error: 93.439550
# Epoch [277 / 500] average reconstruction error: 93.490495
# Epoch [278 / 500] average reconstruction error: 93.370419
# Epoch [279 / 500] average reconstruction error: 93.573879
# Epoch [280 / 500] average reconstruction error: 93.421079
# Epoch [281 / 500] average reconstruction error: 93.546385
# Epoch [282 / 500] average reconstruction error: 93.547500
# Epoch [283 / 500] average reconstruction error: 93.444458
# Epoch [284 / 500] average reconstruction error: 93.515878
# Epoch [285 / 500] average reconstruction error: 93.418544
# Epoch [286 / 500] average reconstruction error: 93.512380
# Epoch [287 / 500] average reconstruction error: 93.605506
# Epoch [288 / 500] average reconstruction error: 93.523916
# Epoch [289 / 500] average reconstruction error: 94.074744
# Epoch [290 / 500] average reconstruction error: 93.416573
# Epoch [291 / 500] average reconstruction error: 93.400647
# Epoch [292 / 500] average reconstruction error: 93.463453
# Epoch [293 / 500] average reconstruction error: 93.578987
# Epoch [294 / 500] average reconstruction error: 93.507615
# Epoch [295 / 500] average reconstruction error: 93.298741
# Epoch [296 / 500] average reconstruction error: 93.570647
# Epoch [297 / 500] average reconstruction error: 93.722581
# Epoch [298 / 500] average reconstruction error: 93.520175
# Epoch [299 / 500] average reconstruction error: 93.565711
# Epoch [300 / 500] average reconstruction error: 93.763288
# Epoch [301 / 500] average reconstruction error: 93.710427
# Epoch [302 / 500] average reconstruction error: 93.353087
# Epoch [303 / 500] average reconstruction error: 93.349263
# Epoch [304 / 500] average reconstruction error: 93.294468
# Epoch [305 / 500] average reconstruction error: 93.443927
# Epoch [306 / 500] average reconstruction error: 93.636763
# Epoch [307 / 500] average reconstruction error: 93.647703
# Epoch [308 / 500] average reconstruction error: 93.713167
# Epoch [309 / 500] average reconstruction error: 93.447726
# Epoch [310 / 500] average reconstruction error: 93.316452
# Epoch [311 / 500] average reconstruction error: 93.684606
# Epoch [312 / 500] average reconstruction error: 93.495822
# Epoch [313 / 500] average reconstruction error: 93.317316
# Epoch [314 / 500] average reconstruction error: 93.537410
# Epoch [315 / 500] average reconstruction error: 93.787935
# Epoch [316 / 500] average reconstruction error: 93.355720
# Epoch [317 / 500] average reconstruction error: 93.389390
# Epoch [318 / 500] average reconstruction error: 93.491506
# Epoch [319 / 500] average reconstruction error: 93.650408
# Epoch [320 / 500] average reconstruction error: 93.615734
# Epoch [321 / 500] average reconstruction error: 93.204912
# Epoch [322 / 500] average reconstruction error: 93.672843
# Epoch [323 / 500] average reconstruction error: 93.680323
# Epoch [324 / 500] average reconstruction error: 93.373986
# Epoch [325 / 500] average reconstruction error: 93.230828
# Epoch [326 / 500] average reconstruction error: 93.623868
# Epoch [327 / 500] average reconstruction error: 93.685094
# Epoch [328 / 500] average reconstruction error: 93.674309
# Epoch [329 / 500] average reconstruction error: 94.138051
# Epoch [330 / 500] average reconstruction error: 93.464597
# Epoch [331 / 500] average reconstruction error: 93.526915
# Epoch [332 / 500] average reconstruction error: 93.438873
# Epoch [333 / 500] average reconstruction error: 93.399798
# Epoch [334 / 500] average reconstruction error: 93.523752
# Epoch [335 / 500] average reconstruction error: 93.387734
# Epoch [336 / 500] average reconstruction error: 93.425978
# Epoch [337 / 500] average reconstruction error: 93.755060
# Epoch [338 / 500] average reconstruction error: 93.375792
# Epoch [339 / 500] average reconstruction error: 93.270610
# Epoch [340 / 500] average reconstruction error: 93.363468
# Epoch [341 / 500] average reconstruction error: 93.340392
# Epoch [342 / 500] average reconstruction error: 93.320606
# Epoch [343 / 500] average reconstruction error: 93.403431
# Epoch [344 / 500] average reconstruction error: 93.351093
# Epoch [345 / 500] average reconstruction error: 93.598518
# Epoch [346 / 500] average reconstruction error: 93.774953
# Epoch [347 / 500] average reconstruction error: 93.502669
# Epoch [348 / 500] average reconstruction error: 93.727698
# Epoch [349 / 500] average reconstruction error: 93.445730
# Epoch [350 / 500] average reconstruction error: 93.220291
# Epoch [351 / 500] average reconstruction error: 93.290611
# Epoch [352 / 500] average reconstruction error: 93.337879
# Epoch [353 / 500] average reconstruction error: 93.347328
# Epoch [354 / 500] average reconstruction error: 93.728599
# Epoch [355 / 500] average reconstruction error: 93.808235
# Epoch [356 / 500] average reconstruction error: 93.362245
# Epoch [357 / 500] average reconstruction error: 93.264410
# Epoch [358 / 500] average reconstruction error: 93.249637
# Epoch [359 / 500] average reconstruction error: 93.385560
# Epoch [360 / 500] average reconstruction error: 93.328679
# Epoch [361 / 500] average reconstruction error: 93.277365
# Epoch [362 / 500] average reconstruction error: 93.469173
# Epoch [363 / 500] average reconstruction error: 93.392099
# Epoch [364 / 500] average reconstruction error: 93.204540
# Epoch [365 / 500] average reconstruction error: 93.277811
# Epoch [366 / 500] average reconstruction error: 93.579889
# Epoch [367 / 500] average reconstruction error: 93.388949
# Epoch [368 / 500] average reconstruction error: 93.353825
# Epoch [369 / 500] average reconstruction error: 93.580012
# Epoch [370 / 500] average reconstruction error: 93.934206
# Epoch [371 / 500] average reconstruction error: 93.407347
# Epoch [372 / 500] average reconstruction error: 93.600696
# Epoch [373 / 500] average reconstruction error: 93.290830
# Epoch [374 / 500] average reconstruction error: 93.135683
# Epoch [375 / 500] average reconstruction error: 93.359111
# Epoch [376 / 500] average reconstruction error: 93.352733
# Epoch [377 / 500] average reconstruction error: 93.382059
# Epoch [378 / 500] average reconstruction error: 93.425019
# Epoch [379 / 500] average reconstruction error: 93.652425
# Epoch [380 / 500] average reconstruction error: 93.628827
# Epoch [381 / 500] average reconstruction error: 93.819302
# Epoch [382 / 500] average reconstruction error: 93.248420
# Epoch [383 / 500] average reconstruction error: 93.238502
# Epoch [384 / 500] average reconstruction error: 93.117908
# Epoch [385 / 500] average reconstruction error: 93.779091
# Epoch [386 / 500] average reconstruction error: 93.453976
# Epoch [387 / 500] average reconstruction error: 93.155705
# Epoch [388 / 500] average reconstruction error: 93.349525
# Epoch [389 / 500] average reconstruction error: 93.290641
# Epoch [390 / 500] average reconstruction error: 93.468179
# Epoch [391 / 500] average reconstruction error: 93.250105
# Epoch [392 / 500] average reconstruction error: 93.427601
# Epoch [393 / 500] average reconstruction error: 93.372611
# Epoch [394 / 500] average reconstruction error: 93.522985
# Epoch [395 / 500] average reconstruction error: 93.359235
# Epoch [396 / 500] average reconstruction error: 93.757700
# Epoch [397 / 500] average reconstruction error: 93.295980
# Epoch [398 / 500] average reconstruction error: 93.248278
# Epoch [399 / 500] average reconstruction error: 93.204242
# Epoch [400 / 500] average reconstruction error: 93.170047
# Epoch [401 / 500] average reconstruction error: 93.093094
# Epoch [402 / 500] average reconstruction error: 93.162518
# Epoch [403 / 500] average reconstruction error: 93.590628
# Epoch [404 / 500] average reconstruction error: 93.515415
# Epoch [405 / 500] average reconstruction error: 93.510938
# Epoch [406 / 500] average reconstruction error: 93.374999
# Epoch [407 / 500] average reconstruction error: 93.489323
# Epoch [408 / 500] average reconstruction error: 93.235565
# Epoch [409 / 500] average reconstruction error: 93.307761
# Epoch [410 / 500] average reconstruction error: 93.392245
# Epoch [411 / 500] average reconstruction error: 93.152650
# Epoch [412 / 500] average reconstruction error: 93.218065
# Epoch [413 / 500] average reconstruction error: 93.497273
# Epoch [414 / 500] average reconstruction error: 93.261555
# Epoch [415 / 500] average reconstruction error: 93.123816
# Epoch [416 / 500] average reconstruction error: 93.202429
# Epoch [417 / 500] average reconstruction error: 93.153169
# Epoch [418 / 500] average reconstruction error: 93.048888
# Epoch [419 / 500] average reconstruction error: 93.271821
# Epoch [420 / 500] average reconstruction error: 93.398853
# Epoch [421 / 500] average reconstruction error: 93.344083
# Epoch [422 / 500] average reconstruction error: 93.530536
# Epoch [423 / 500] average reconstruction error: 93.826621
# Epoch [424 / 500] average reconstruction error: 93.239622
# Epoch [425 / 500] average reconstruction error: 93.076566
# Epoch [426 / 500] average reconstruction error: 93.158562
# Epoch [427 / 500] average reconstruction error: 93.563433
# Epoch [428 / 500] average reconstruction error: 93.595161
# Epoch [429 / 500] average reconstruction error: 93.134756
# Epoch [430 / 500] average reconstruction error: 93.162100
# Epoch [431 / 500] average reconstruction error: 93.257817
# Epoch [432 / 500] average reconstruction error: 93.267345
# Epoch [433 / 500] average reconstruction error: 93.077751
# Epoch [434 / 500] average reconstruction error: 93.056226
# Epoch [435 / 500] average reconstruction error: 93.372187
# Epoch [436 / 500] average reconstruction error: 93.344403
# Epoch [437 / 500] average reconstruction error: 93.306394
# Epoch [438 / 500] average reconstruction error: 93.279649
# Epoch [439 / 500] average reconstruction error: 93.416823
# Epoch [440 / 500] average reconstruction error: 93.229083
# Epoch [441 / 500] average reconstruction error: 93.335108
# Epoch [442 / 500] average reconstruction error: 93.178941
# Epoch [443 / 500] average reconstruction error: 93.193970
# Epoch [444 / 500] average reconstruction error: 93.329401
# Epoch [445 / 500] average reconstruction error: 93.323963
# Epoch [446 / 500] average reconstruction error: 93.316338
# Epoch [447 / 500] average reconstruction error: 93.202651
# Epoch [448 / 500] average reconstruction error: 93.184055
# Epoch [449 / 500] average reconstruction error: 93.214167
# Epoch [450 / 500] average reconstruction error: 93.164043
# Epoch [451 / 500] average reconstruction error: 93.416847
# Epoch [452 / 500] average reconstruction error: 93.189435
# Epoch [453 / 500] average reconstruction error: 93.143728
# Epoch [454 / 500] average reconstruction error: 93.172237
# Epoch [455 / 500] average reconstruction error: 93.315785
# Epoch [456 / 500] average reconstruction error: 93.332596
# Epoch [457 / 500] average reconstruction error: 93.222300
# Epoch [458 / 500] average reconstruction error: 93.602178
# Epoch [459 / 500] average reconstruction error: 93.136786
# Epoch [460 / 500] average reconstruction error: 93.098269
# Epoch [461 / 500] average reconstruction error: 92.988077
# Epoch [462 / 500] average reconstruction error: 93.492822
# Epoch [463 / 500] average reconstruction error: 93.291416
# Epoch [464 / 500] average reconstruction error: 93.234017
# Epoch [465 / 500] average reconstruction error: 94.281261
# Epoch [466 / 500] average reconstruction error: 93.232573
# Epoch [467 / 500] average reconstruction error: 93.095472
# Epoch [468 / 500] average reconstruction error: 93.083721
# Epoch [469 / 500] average reconstruction error: 93.043646
# Epoch [470 / 500] average reconstruction error: 93.015087
# Epoch [471 / 500] average reconstruction error: 93.107718
# Epoch [472 / 500] average reconstruction error: 93.182617
# Epoch [473 / 500] average reconstruction error: 93.252553
# Epoch [474 / 500] average reconstruction error: 93.383872
# Epoch [475 / 500] average reconstruction error: 93.188843
# Epoch [476 / 500] average reconstruction error: 93.135609
# Epoch [477 / 500] average reconstruction error: 93.298337
# Epoch [478 / 500] average reconstruction error: 93.078090
# Epoch [479 / 500] average reconstruction error: 93.102207
# Epoch [480 / 500] average reconstruction error: 93.095788
# Epoch [481 / 500] average reconstruction error: 93.505319
# Epoch [482 / 500] average reconstruction error: 93.277144
# Epoch [483 / 500] average reconstruction error: 93.071308
# Epoch [484 / 500] average reconstruction error: 93.125445
# Epoch [485 / 500] average reconstruction error: 93.653966
# Epoch [486 / 500] average reconstruction error: 93.181525
# Epoch [487 / 500] average reconstruction error: 93.155276
# Epoch [488 / 500] average reconstruction error: 93.410383
# Epoch [489 / 500] average reconstruction error: 93.133778
# Epoch [490 / 500] average reconstruction error: 93.345532
# Epoch [491 / 500] average reconstruction error: 93.212935
# Epoch [492 / 500] average reconstruction error: 93.142811
# Epoch [493 / 500] average reconstruction error: 93.118310
# Epoch [494 / 500] average reconstruction error: 93.148705
# Epoch [495 / 500] average reconstruction error: 93.112419
# Epoch [496 / 500] average reconstruction error: 93.166502
# Epoch [497 / 500] average reconstruction error: 93.143200
# Epoch [498 / 500] average reconstruction error: 93.218182
# Epoch [499 / 500] average reconstruction error: 93.225578
# Epoch [500 / 500] average reconstruction error: 92.973004

# %% [markdown]
# # Affichage de la courbe de loss

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Evaluation du score sur le Dataset de TEST

# %%
# set to evaluation mode
vae.eval()

test_loss_avg, num_batches = 0, 0
for image_batch in test_dataloader:
    
    with torch.no_grad():
    
        #image_batch = image_batch.to(device)
        image_batch = torch.DoubleTensor(image_batch[0])
        Max_image_batch = torch.max(image_batch)
        image_batch = image_batch.view(batch_size,1,2,750)/Max_image_batch
        image_batch = image_batch.float()
        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)

        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

        test_loss_avg += loss.item()
        num_batches += 1
    
test_loss_avg /= num_batches
print('average reconstruction error: %f' % (test_loss_avg))
# Out:
# average reconstruction error: 93.320660

# %% [markdown]
# # Reconstruction

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

# En entrée, l'image à reconstruire et le modèle utilisé pour la reconstruction



def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()

images = iter(test_dataloader).next()

# Affichage de l'image originale
print('Image originale')

images = torch.DoubleTensor(images[0])
images = images.view(batch_size,1,2,750)
plt.figure()
plt.subplot(1,2,1)
plt.plot((images[0,0,0,:]))
plt.subplot(1,2,2)
plt.plot((images[0,0,1,:]))        
plt.show()

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
images, _, _ = vae(images.float())
images = images.detach().numpy()
plt.figure()
plt.subplot(1,2,1)
plt.plot((images[0,0,0,:]))
plt.subplot(1,2,2)
plt.plot((images[0,0,1,:]))        
plt.show()
# Out:
# Image originale
# VAE reconstruction:

# %% [markdown]
# # Affichage de la courbe de loss

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # Reconstruction

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

# En entrée, l'image à reconstruire et le modèle utilisé pour la reconstruction



def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()

images, labels = iter(test_dataloader).next()

# Affichage de l'image originale
print('Image originale')
show_image(torchvision.utils.make_grid(images[1:50],10,5))
plt.show()

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
visualise_output(images, vae)

# %% [markdown]
# # Interpolation dans l'espace latent

# %%
vae.eval()

def interpolation(lambda1, model, img1, img2):
    
    with torch.no_grad():
    
        # latent vector of first image
        img1 = img1.to(device)
        latent_1, _ = model.encoder(img1)

        # latent vector of second image
        img2 = img2.to(device)
        latent_2, _ = model.encoder(img2)

        # interpolation of the two latent vectors
        inter_latent = lambda1* latent_1 + (1- lambda1) * latent_2

        # reconstruct interpolated image
        inter_image = model.decoder(inter_latent)
        inter_image = inter_image.cpu()

        return inter_image
    
# sort part of test set by digit
digits = [[] for _ in range(10)]
for img_batch, label_batch in test_dataloader:
    for i in range(img_batch.size(0)):
        digits[label_batch[i]].append(img_batch[i:i+1])
    if sum(len(d) for d in digits) >= 1000:
        break;

# interpolation lambdas
lambda_range=np.linspace(0,1,10)

fig, axs = plt.subplots(2,5, figsize=(15, 6))
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for ind,l in enumerate(lambda_range):
    inter_image=interpolation(float(l), vae, digits[7][0], digits[1][0])
   
    inter_image = to_img(inter_image)
    
    image = inter_image.numpy()
   
    axs[ind].imshow(image[0,0,:,:], cmap='gray')
    axs[ind].set_title('lambda_val='+str(round(l,1)))
plt.show()

# %% [markdown]
# # Utilisation du VAE comme générateur
#
# Un autoencodeur variationnel peut générer de nouveaux chiffres en tirant des vecteurs latents de la distribution précédente. Les chiffres générés ne sont bien sûr pas parfaits

# %%
vae.eval()

with torch.no_grad():

    # sample latent vectors from the normal distribution
    latent = torch.randn(128, latent_dims, device=device)

    # reconstruct images from the latent vectors
    img_recon = vae.decoder(latent)
    img_recon = img_recon.cpu()

    fig, ax = plt.subplots(figsize=(5, 5))
    show_image(torchvision.utils.make_grid(img_recon.data[:100],10,5))
    plt.show()

# %% [markdown]
# # Espace latent 2D

# %%
# load a network that was trained with a 2d latent space
if latent_dims != 2:
    print('Please change the parameters to two latent dimensions.')
    
with torch.no_grad():
    
    # create a sample grid in 2d latent space
    latent_x = np.linspace(-1.5,1.5,20)
    latent_y = np.linspace(-1.5,1.5,20)
    latents = torch.FloatTensor(len(latent_y), len(latent_x), 2)
    for i, lx in enumerate(latent_x):
        for j, ly in enumerate(latent_y):
            latents[j, i, 0] = lx
            latents[j, i, 1] = ly
    latents = latents.view(-1, 2) # flatten grid into a batch

    # reconstruct images from the latent vectors
    latents = latents.to(device)
    image_recon = vae.decoder(latents)
    image_recon = image_recon.cpu()

    fig, ax = plt.subplots(figsize=(10, 10))
    show_image(torchvision.utils.make_grid(image_recon.data[:400],20,5))
    plt.show()

# %%
13500/750
# Out:
# 18.0
