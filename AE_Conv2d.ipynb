# %%
# %matplotlib inline
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
###### Espace latent 2 dimensions

latent_dims = 1024
num_epochs = 500
batch_size = 25
capacity = 2
learning_rate = 5e-4

# %% [markdown]
# # Chargement des données

# %%
import os
import descriptors
import numpy as np

dict_r = np.load('data_dict.npy', allow_pickle=True).item()

train_db = np.zeros([len(dict_r['env']),2,750])


i = 0
for sample in dict_r['env']:
    train_db[i,:,:] = sample
    i+=1
    
MAX1 = np.max(train_db[:,0,:])*5
MAX2 = np.max(train_db[:,1,:])
train_db[:,0,:] /= MAX1
train_db[:,1,:] /= (MAX2)
train_dataset =  torch.utils.data.TensorDataset(torch.from_numpy(train_db))

print(train_db.shape)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, drop_last = True)

test_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, drop_last = True)
# Out:
# (252, 2, 750)

# %% [markdown]
# # Defintion du AE
#
# Kernel Size = 4 papier qui explique pourquoi: https://distill.pub/2016/deconv-checkerboard/

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity     
        self.conv1 = nn.Sequential(nn.Conv1d(in_channels=2, out_channels=c, kernel_size=10, stride=2, padding=7), nn.BatchNorm1d(c)) # out: c, 372
        self.conv2 = nn.Sequential(nn.Conv1d(in_channels=c, out_channels=c*2, kernel_size=5, stride=2, padding=7), nn.BatchNorm1d(2*c)) # out: c*2, 186
        self.conv3 = nn.Sequential(nn.Conv1d(in_channels=c*2, out_channels=c*4, kernel_size=5, stride=2, padding=2), nn.BatchNorm1d(4*c)) # out: c*2, 186
        self.conv4 = nn.Sequential(nn.Conv1d(in_channels=c*4, out_channels=c*8, kernel_size=5, stride=2, padding=2), nn.BatchNorm1d(8*c)) # out: c*2, 186
        self.conv5 = nn.Sequential(nn.Conv1d(in_channels=c*8, out_channels=c*8, kernel_size=5, stride=1, padding=2), nn.BatchNorm1d(8*c)) # out: c*2, 186
        self.lin1 = nn.Linear(8*c*49, latent_dims)
       
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = x.view(x.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        x = F.relu(self.lin1(x))
        return x

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.lin1 = nn.Linear(latent_dims, 8*c*49)
        self.conv5 = nn.Sequential(nn.ConvTranspose1d(in_channels=c*8, out_channels=c*8, kernel_size=5, stride=1, padding=2, output_padding=0), nn.BatchNorm1d(c*8))
        self.conv4 = nn.Sequential(nn.ConvTranspose1d(in_channels=c*8, out_channels=c*4, kernel_size=5, stride=2, padding=2, output_padding=0), nn.BatchNorm1d(c*4))
        self.conv3 = nn.Sequential(nn.ConvTranspose1d(in_channels=c*4, out_channels=c*2, kernel_size=5, stride=2, padding=2, output_padding=1), nn.BatchNorm1d(c*2))
        self.conv2 = nn.Sequential(nn.ConvTranspose1d(in_channels=c*2, out_channels=c, kernel_size=5, stride=2, padding=7, output_padding=1), nn.BatchNorm1d(c))
        self.conv1 = nn.Sequential(nn.ConvTranspose1d(in_channels=c, out_channels=2, kernel_size=10, stride=2, padding=7, output_padding=0), nn.BatchNorm1d(2))
            
    def forward(self, x):
        x = F.relu(self.lin1(x))
        x = x.view(x.size(0), capacity*8, 49) # unflatten batch of feature vectors to a batch of multi-channel feature maps
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv1(x)) # last layer before output is sigmoid, since we are using BCE as reconstruction loss
        return x
    
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def forward(self, x):
        x = self.encoder(x)
        x_recon = self.decoder(x)
        return x_recon
    
def ae_loss(recon_x, x):
    recon_loss = F.binary_cross_entropy(recon_x, x, reduction='mean')
    return recon_loss
    
ae = Autoencoder()

num_params = sum(p.numel() for p in ae.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 1611994

# %% [markdown]
# # Entrainement

# %%
optimizer = torch.optim.Adam(params=ae.parameters(), lr=learning_rate, weight_decay=1e-5)

# set to training mode
ae.train()

train_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    
    for image_batch in train_loader:

        #image_batch = image_batch.to(device)
        image_batch = torch.DoubleTensor(image_batch[0])
        image_batch = image_batch.view(batch_size,2,750)
        
        # vae reconstruction
        image_batch_recon = ae(image_batch.float())
        
        # reconstruction error
        loss = F.mse_loss(image_batch_recon, image_batch.float())
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        
        # one step of the optmizer (using the gradients from backpropagation)
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()

        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    
    print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
# Out:
# Training ...
# C:\Users\gabri\Anaconda3\lib\site-packages\torch\autograd\__init__.py:132: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 9010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   allow_unreachable=True)  # allow_unreachable flag
# Epoch [1 / 500] average reconstruction error: 0.107561
# Epoch [2 / 500] average reconstruction error: 0.095576
# Epoch [3 / 500] average reconstruction error: 0.091785
# Epoch [4 / 500] average reconstruction error: 0.088026
# Epoch [5 / 500] average reconstruction error: 0.083439
# Epoch [6 / 500] average reconstruction error: 0.079796
# Epoch [7 / 500] average reconstruction error: 0.077407
# Epoch [8 / 500] average reconstruction error: 0.074920
# Epoch [9 / 500] average reconstruction error: 0.072632
# Epoch [10 / 500] average reconstruction error: 0.071492
# Epoch [11 / 500] average reconstruction error: 0.069958
# Epoch [12 / 500] average reconstruction error: 0.068693
# Epoch [13 / 500] average reconstruction error: 0.067515
# Epoch [14 / 500] average reconstruction error: 0.066167
# Epoch [15 / 500] average reconstruction error: 0.063704
# Epoch [16 / 500] average reconstruction error: 0.063046
# Epoch [17 / 500] average reconstruction error: 0.062131
# Epoch [18 / 500] average reconstruction error: 0.061081
# Epoch [19 / 500] average reconstruction error: 0.060100
# Epoch [20 / 500] average reconstruction error: 0.059489
# Epoch [21 / 500] average reconstruction error: 0.059261
# Epoch [22 / 500] average reconstruction error: 0.058611
# Epoch [23 / 500] average reconstruction error: 0.057364
# Epoch [24 / 500] average reconstruction error: 0.057598
# Epoch [25 / 500] average reconstruction error: 0.057002
# Epoch [26 / 500] average reconstruction error: 0.056504
# Epoch [27 / 500] average reconstruction error: 0.055521
# Epoch [28 / 500] average reconstruction error: 0.054844
# Epoch [29 / 500] average reconstruction error: 0.054341
# Epoch [30 / 500] average reconstruction error: 0.053698
# Epoch [31 / 500] average reconstruction error: 0.053628
# Epoch [32 / 500] average reconstruction error: 0.053317
# Epoch [33 / 500] average reconstruction error: 0.051956
# Epoch [34 / 500] average reconstruction error: 0.052746
# Epoch [35 / 500] average reconstruction error: 0.051656
# Epoch [36 / 500] average reconstruction error: 0.051068
# Epoch [37 / 500] average reconstruction error: 0.052036
# Epoch [38 / 500] average reconstruction error: 0.050214
# Epoch [39 / 500] average reconstruction error: 0.050556
# Epoch [40 / 500] average reconstruction error: 0.049536
# Epoch [41 / 500] average reconstruction error: 0.049800
# Epoch [42 / 500] average reconstruction error: 0.048112
# Epoch [43 / 500] average reconstruction error: 0.048127
# Epoch [44 / 500] average reconstruction error: 0.047595
# Epoch [45 / 500] average reconstruction error: 0.047530
# Epoch [46 / 500] average reconstruction error: 0.046829
# Epoch [47 / 500] average reconstruction error: 0.047156
# Epoch [48 / 500] average reconstruction error: 0.045808
# Epoch [49 / 500] average reconstruction error: 0.045924
# Epoch [50 / 500] average reconstruction error: 0.045908
# Epoch [51 / 500] average reconstruction error: 0.044616
# Epoch [52 / 500] average reconstruction error: 0.044273
# Epoch [53 / 500] average reconstruction error: 0.044322
# Epoch [54 / 500] average reconstruction error: 0.043854
# Epoch [55 / 500] average reconstruction error: 0.042942
# Epoch [56 / 500] average reconstruction error: 0.044656
# Epoch [57 / 500] average reconstruction error: 0.042974
# Epoch [58 / 500] average reconstruction error: 0.042729
# Epoch [59 / 500] average reconstruction error: 0.043006
# Epoch [60 / 500] average reconstruction error: 0.042286
# Epoch [61 / 500] average reconstruction error: 0.041920
# Epoch [62 / 500] average reconstruction error: 0.040798
# Epoch [63 / 500] average reconstruction error: 0.040444
# Epoch [64 / 500] average reconstruction error: 0.040674
# Epoch [65 / 500] average reconstruction error: 0.040463
# Epoch [66 / 500] average reconstruction error: 0.040236
# Epoch [67 / 500] average reconstruction error: 0.039310
# Epoch [68 / 500] average reconstruction error: 0.038685
# Epoch [69 / 500] average reconstruction error: 0.039008
# Epoch [70 / 500] average reconstruction error: 0.038251
# Epoch [71 / 500] average reconstruction error: 0.038815
# Epoch [72 / 500] average reconstruction error: 0.039487
# Epoch [73 / 500] average reconstruction error: 0.038092
# Epoch [74 / 500] average reconstruction error: 0.036978
# Epoch [75 / 500] average reconstruction error: 0.036501
# Epoch [76 / 500] average reconstruction error: 0.036794
# Epoch [77 / 500] average reconstruction error: 0.036958
# Epoch [78 / 500] average reconstruction error: 0.036104
# Epoch [79 / 500] average reconstruction error: 0.036535
# Epoch [80 / 500] average reconstruction error: 0.034831
# Epoch [81 / 500] average reconstruction error: 0.035012
# Epoch [82 / 500] average reconstruction error: 0.034469
# Epoch [83 / 500] average reconstruction error: 0.034564
# Epoch [84 / 500] average reconstruction error: 0.034696
# Epoch [85 / 500] average reconstruction error: 0.034599
# Epoch [86 / 500] average reconstruction error: 0.033363
# Epoch [87 / 500] average reconstruction error: 0.033577
# Epoch [88 / 500] average reconstruction error: 0.033116
# Epoch [89 / 500] average reconstruction error: 0.032829
# Epoch [90 / 500] average reconstruction error: 0.032450
# Epoch [91 / 500] average reconstruction error: 0.031827
# Epoch [92 / 500] average reconstruction error: 0.031901
# Epoch [93 / 500] average reconstruction error: 0.031338
# Epoch [94 / 500] average reconstruction error: 0.032308
# Epoch [95 / 500] average reconstruction error: 0.031260
# Epoch [96 / 500] average reconstruction error: 0.031043
# Epoch [97 / 500] average reconstruction error: 0.031006
# Epoch [98 / 500] average reconstruction error: 0.030774
# Epoch [99 / 500] average reconstruction error: 0.031132
# Epoch [100 / 500] average reconstruction error: 0.030162
# Epoch [101 / 500] average reconstruction error: 0.029975
# Epoch [102 / 500] average reconstruction error: 0.029859
# Epoch [103 / 500] average reconstruction error: 0.029656
# Epoch [104 / 500] average reconstruction error: 0.029433
# Epoch [105 / 500] average reconstruction error: 0.029609
# Epoch [106 / 500] average reconstruction error: 0.029811
# Epoch [107 / 500] average reconstruction error: 0.028490
# Epoch [108 / 500] average reconstruction error: 0.028166
# Epoch [109 / 500] average reconstruction error: 0.028135
# Epoch [110 / 500] average reconstruction error: 0.027807
# Epoch [111 / 500] average reconstruction error: 0.028504
# Epoch [112 / 500] average reconstruction error: 0.027389
# Epoch [113 / 500] average reconstruction error: 0.028212
# Epoch [114 / 500] average reconstruction error: 0.027190
# Epoch [115 / 500] average reconstruction error: 0.026835
# Epoch [116 / 500] average reconstruction error: 0.027987
# Epoch [117 / 500] average reconstruction error: 0.025953
# Epoch [118 / 500] average reconstruction error: 0.026838
# Epoch [119 / 500] average reconstruction error: 0.025777
# Epoch [120 / 500] average reconstruction error: 0.027575
# Epoch [121 / 500] average reconstruction error: 0.026512
# Epoch [122 / 500] average reconstruction error: 0.026045
# Epoch [123 / 500] average reconstruction error: 0.024967
# Epoch [124 / 500] average reconstruction error: 0.025133
# Epoch [125 / 500] average reconstruction error: 0.024543
# Epoch [126 / 500] average reconstruction error: 0.024342
# Epoch [127 / 500] average reconstruction error: 0.024459
# Epoch [128 / 500] average reconstruction error: 0.024064
# Epoch [129 / 500] average reconstruction error: 0.024588
# Epoch [130 / 500] average reconstruction error: 0.024000
# Epoch [131 / 500] average reconstruction error: 0.023950
# Epoch [132 / 500] average reconstruction error: 0.024044
# Epoch [133 / 500] average reconstruction error: 0.024000
# Epoch [134 / 500] average reconstruction error: 0.023351
# Epoch [135 / 500] average reconstruction error: 0.022903
# Epoch [136 / 500] average reconstruction error: 0.022527
# Epoch [137 / 500] average reconstruction error: 0.023250
# Epoch [138 / 500] average reconstruction error: 0.023127
# Epoch [139 / 500] average reconstruction error: 0.022770
# Epoch [140 / 500] average reconstruction error: 0.021811
# Epoch [141 / 500] average reconstruction error: 0.022767
# Epoch [142 / 500] average reconstruction error: 0.021571
# Epoch [143 / 500] average reconstruction error: 0.021445
# Epoch [144 / 500] average reconstruction error: 0.021392
# Epoch [145 / 500] average reconstruction error: 0.021576
# Epoch [146 / 500] average reconstruction error: 0.021517
# Epoch [147 / 500] average reconstruction error: 0.021433
# Epoch [148 / 500] average reconstruction error: 0.020797
# Epoch [149 / 500] average reconstruction error: 0.021004
# Epoch [150 / 500] average reconstruction error: 0.021369
# Epoch [151 / 500] average reconstruction error: 0.020815
# Epoch [152 / 500] average reconstruction error: 0.020415
# Epoch [153 / 500] average reconstruction error: 0.019929
# Epoch [154 / 500] average reconstruction error: 0.019514
# Epoch [155 / 500] average reconstruction error: 0.019464
# Epoch [156 / 500] average reconstruction error: 0.020193
# Epoch [157 / 500] average reconstruction error: 0.020494
# Epoch [158 / 500] average reconstruction error: 0.020889
# Epoch [159 / 500] average reconstruction error: 0.019572
# Epoch [160 / 500] average reconstruction error: 0.018529
# Epoch [161 / 500] average reconstruction error: 0.019122
# Epoch [162 / 500] average reconstruction error: 0.019726
# Epoch [163 / 500] average reconstruction error: 0.018940
# Epoch [164 / 500] average reconstruction error: 0.018961
# Epoch [165 / 500] average reconstruction error: 0.018363
# Epoch [166 / 500] average reconstruction error: 0.018250
# Epoch [167 / 500] average reconstruction error: 0.018105
# Epoch [168 / 500] average reconstruction error: 0.017502
# Epoch [169 / 500] average reconstruction error: 0.017861
# Epoch [170 / 500] average reconstruction error: 0.017367
# Epoch [171 / 500] average reconstruction error: 0.017414
# Epoch [172 / 500] average reconstruction error: 0.017209
# Epoch [173 / 500] average reconstruction error: 0.017067
# Epoch [174 / 500] average reconstruction error: 0.016988
# Epoch [175 / 500] average reconstruction error: 0.017756
# Epoch [176 / 500] average reconstruction error: 0.016974
# Epoch [177 / 500] average reconstruction error: 0.016966
# Epoch [178 / 500] average reconstruction error: 0.016694
# Epoch [179 / 500] average reconstruction error: 0.016557
# Epoch [180 / 500] average reconstruction error: 0.018635
# Epoch [181 / 500] average reconstruction error: 0.017257
# Epoch [182 / 500] average reconstruction error: 0.016806
# Epoch [183 / 500] average reconstruction error: 0.018053
# Epoch [184 / 500] average reconstruction error: 0.016341
# Epoch [185 / 500] average reconstruction error: 0.017393
# Epoch [186 / 500] average reconstruction error: 0.016501
# Epoch [187 / 500] average reconstruction error: 0.016196
# Epoch [188 / 500] average reconstruction error: 0.016423
# Epoch [189 / 500] average reconstruction error: 0.015976
# Epoch [190 / 500] average reconstruction error: 0.015467
# Epoch [191 / 500] average reconstruction error: 0.015714
# Epoch [192 / 500] average reconstruction error: 0.015922
# Epoch [193 / 500] average reconstruction error: 0.015227
# Epoch [194 / 500] average reconstruction error: 0.014708
# Epoch [195 / 500] average reconstruction error: 0.014873
# Epoch [196 / 500] average reconstruction error: 0.015571
# Epoch [197 / 500] average reconstruction error: 0.014868
# Epoch [198 / 500] average reconstruction error: 0.014546
# Epoch [199 / 500] average reconstruction error: 0.015209
# Epoch [200 / 500] average reconstruction error: 0.015582
# Epoch [201 / 500] average reconstruction error: 0.014540
# Epoch [202 / 500] average reconstruction error: 0.014319
# Epoch [203 / 500] average reconstruction error: 0.014382
# Epoch [204 / 500] average reconstruction error: 0.014019
# Epoch [205 / 500] average reconstruction error: 0.014033
# Epoch [206 / 500] average reconstruction error: 0.014345
# Epoch [207 / 500] average reconstruction error: 0.013357
# Epoch [208 / 500] average reconstruction error: 0.013770
# Epoch [209 / 500] average reconstruction error: 0.014329
# Epoch [210 / 500] average reconstruction error: 0.013037
# Epoch [211 / 500] average reconstruction error: 0.013228
# Epoch [212 / 500] average reconstruction error: 0.012975
# Epoch [213 / 500] average reconstruction error: 0.013771
# Epoch [214 / 500] average reconstruction error: 0.013248
# Epoch [215 / 500] average reconstruction error: 0.012770
# Epoch [216 / 500] average reconstruction error: 0.012616
# Epoch [217 / 500] average reconstruction error: 0.012992
# Epoch [218 / 500] average reconstruction error: 0.012051
# Epoch [219 / 500] average reconstruction error: 0.012286
# Epoch [220 / 500] average reconstruction error: 0.012618
# Epoch [221 / 500] average reconstruction error: 0.011920
# Epoch [222 / 500] average reconstruction error: 0.013068
# Epoch [223 / 500] average reconstruction error: 0.011915
# Epoch [224 / 500] average reconstruction error: 0.012546
# Epoch [225 / 500] average reconstruction error: 0.011299
# Epoch [226 / 500] average reconstruction error: 0.011984
# Epoch [227 / 500] average reconstruction error: 0.012951
# Epoch [228 / 500] average reconstruction error: 0.011424
# Epoch [229 / 500] average reconstruction error: 0.011542
# Epoch [230 / 500] average reconstruction error: 0.011354
# Epoch [231 / 500] average reconstruction error: 0.012052
# Epoch [232 / 500] average reconstruction error: 0.010960
# Epoch [233 / 500] average reconstruction error: 0.011329
# Epoch [234 / 500] average reconstruction error: 0.011580
# Epoch [235 / 500] average reconstruction error: 0.011660
# Epoch [236 / 500] average reconstruction error: 0.010786
# Epoch [237 / 500] average reconstruction error: 0.010836
# Epoch [238 / 500] average reconstruction error: 0.010432
# Epoch [239 / 500] average reconstruction error: 0.010810
# Epoch [240 / 500] average reconstruction error: 0.010514
# Epoch [241 / 500] average reconstruction error: 0.010865
# Epoch [242 / 500] average reconstruction error: 0.010589
# Epoch [243 / 500] average reconstruction error: 0.010616
# Epoch [244 / 500] average reconstruction error: 0.010799
# Epoch [245 / 500] average reconstruction error: 0.010441
# Epoch [246 / 500] average reconstruction error: 0.009932
# Epoch [247 / 500] average reconstruction error: 0.010233
# Epoch [248 / 500] average reconstruction error: 0.010523
# Epoch [249 / 500] average reconstruction error: 0.009296
# Epoch [250 / 500] average reconstruction error: 0.016101
# Epoch [251 / 500] average reconstruction error: 0.010078
# Epoch [252 / 500] average reconstruction error: 0.009690
# Epoch [253 / 500] average reconstruction error: 0.010036
# Epoch [254 / 500] average reconstruction error: 0.009437
# Epoch [255 / 500] average reconstruction error: 0.010282
# Epoch [256 / 500] average reconstruction error: 0.009489
# Epoch [257 / 500] average reconstruction error: 0.010017
# Epoch [258 / 500] average reconstruction error: 0.009458
# Epoch [259 / 500] average reconstruction error: 0.009756
# Epoch [260 / 500] average reconstruction error: 0.008932
# Epoch [261 / 500] average reconstruction error: 0.008877
# Epoch [262 / 500] average reconstruction error: 0.009705
# Epoch [263 / 500] average reconstruction error: 0.012583
# Epoch [264 / 500] average reconstruction error: 0.010066
# Epoch [265 / 500] average reconstruction error: 0.009627
# Epoch [266 / 500] average reconstruction error: 0.010029
# Epoch [267 / 500] average reconstruction error: 0.009644
# Epoch [268 / 500] average reconstruction error: 0.009395
# Epoch [269 / 500] average reconstruction error: 0.009553
# Epoch [270 / 500] average reconstruction error: 0.009445
# Epoch [271 / 500] average reconstruction error: 0.008958
# Epoch [272 / 500] average reconstruction error: 0.009121
# Epoch [273 / 500] average reconstruction error: 0.009445
# Epoch [274 / 500] average reconstruction error: 0.009859
# Epoch [275 / 500] average reconstruction error: 0.008791
# Epoch [276 / 500] average reconstruction error: 0.009144
# Epoch [277 / 500] average reconstruction error: 0.009472
# Epoch [278 / 500] average reconstruction error: 0.009636
# Epoch [279 / 500] average reconstruction error: 0.009584
# Epoch [280 / 500] average reconstruction error: 0.009669
# Epoch [281 / 500] average reconstruction error: 0.008555
# Epoch [282 / 500] average reconstruction error: 0.008693
# Epoch [283 / 500] average reconstruction error: 0.008588
# Epoch [284 / 500] average reconstruction error: 0.008368
# Epoch [285 / 500] average reconstruction error: 0.008183
# Epoch [286 / 500] average reconstruction error: 0.008519
# Epoch [287 / 500] average reconstruction error: 0.008608
# Epoch [288 / 500] average reconstruction error: 0.008802
# Epoch [289 / 500] average reconstruction error: 0.007995
# Epoch [290 / 500] average reconstruction error: 0.007887
# Epoch [291 / 500] average reconstruction error: 0.007987
# Epoch [292 / 500] average reconstruction error: 0.007585
# Epoch [293 / 500] average reconstruction error: 0.007848
# Epoch [294 / 500] average reconstruction error: 0.007818
# Epoch [295 / 500] average reconstruction error: 0.007422
# Epoch [296 / 500] average reconstruction error: 0.007378
# Epoch [297 / 500] average reconstruction error: 0.007374
# Epoch [298 / 500] average reconstruction error: 0.007437
# Epoch [299 / 500] average reconstruction error: 0.007321
# Epoch [300 / 500] average reconstruction error: 0.007585
# Epoch [301 / 500] average reconstruction error: 0.007267
# Epoch [302 / 500] average reconstruction error: 0.007049
# Epoch [303 / 500] average reconstruction error: 0.007432
# Epoch [304 / 500] average reconstruction error: 0.007265
# Epoch [305 / 500] average reconstruction error: 0.006981
# Epoch [306 / 500] average reconstruction error: 0.007816
# Epoch [307 / 500] average reconstruction error: 0.007087
# Epoch [308 / 500] average reconstruction error: 0.007557
# Epoch [309 / 500] average reconstruction error: 0.007215
# Epoch [310 / 500] average reconstruction error: 0.008118
# Epoch [311 / 500] average reconstruction error: 0.006970
# Epoch [312 / 500] average reconstruction error: 0.006561
# Epoch [313 / 500] average reconstruction error: 0.007314
# Epoch [314 / 500] average reconstruction error: 0.006979
# Epoch [315 / 500] average reconstruction error: 0.007555
# Epoch [316 / 500] average reconstruction error: 0.007166
# Epoch [317 / 500] average reconstruction error: 0.007689
# Epoch [318 / 500] average reconstruction error: 0.006949
# Epoch [319 / 500] average reconstruction error: 0.006831
# Epoch [320 / 500] average reconstruction error: 0.007433
# Epoch [321 / 500] average reconstruction error: 0.006478
# Epoch [322 / 500] average reconstruction error: 0.006221
# Epoch [323 / 500] average reconstruction error: 0.006678
# Epoch [324 / 500] average reconstruction error: 0.006490
# Epoch [325 / 500] average reconstruction error: 0.005752
# Epoch [326 / 500] average reconstruction error: 0.006356
# Epoch [327 / 500] average reconstruction error: 0.005722
# Epoch [328 / 500] average reconstruction error: 0.005962
# Epoch [329 / 500] average reconstruction error: 0.006073
# Epoch [330 / 500] average reconstruction error: 0.005892
# Epoch [331 / 500] average reconstruction error: 0.005829
# Epoch [332 / 500] average reconstruction error: 0.006152
# Epoch [333 / 500] average reconstruction error: 0.005771
# Epoch [334 / 500] average reconstruction error: 0.006230
# Epoch [335 / 500] average reconstruction error: 0.006587
# Epoch [336 / 500] average reconstruction error: 0.005605
# Epoch [337 / 500] average reconstruction error: 0.006103
# Epoch [338 / 500] average reconstruction error: 0.005801
# Epoch [339 / 500] average reconstruction error: 0.005058
# Epoch [340 / 500] average reconstruction error: 0.005188
# Epoch [341 / 500] average reconstruction error: 0.005494
# Epoch [342 / 500] average reconstruction error: 0.005263
# Epoch [343 / 500] average reconstruction error: 0.011098
# Epoch [344 / 500] average reconstruction error: 0.010180
# Epoch [345 / 500] average reconstruction error: 0.009244
# Epoch [346 / 500] average reconstruction error: 0.006029
# Epoch [347 / 500] average reconstruction error: 0.005732
# Epoch [348 / 500] average reconstruction error: 0.006343
# Epoch [349 / 500] average reconstruction error: 0.005814
# Epoch [350 / 500] average reconstruction error: 0.005927
# Epoch [351 / 500] average reconstruction error: 0.006027
# Epoch [352 / 500] average reconstruction error: 0.006123
# Epoch [353 / 500] average reconstruction error: 0.005888
# Epoch [354 / 500] average reconstruction error: 0.005735
# Epoch [355 / 500] average reconstruction error: 0.005131
# Epoch [356 / 500] average reconstruction error: 0.005559
# Epoch [357 / 500] average reconstruction error: 0.006666
# Epoch [358 / 500] average reconstruction error: 0.005655
# Epoch [359 / 500] average reconstruction error: 0.005458
# Epoch [360 / 500] average reconstruction error: 0.005474
# Epoch [361 / 500] average reconstruction error: 0.005688
# Epoch [362 / 500] average reconstruction error: 0.005287
# Epoch [363 / 500] average reconstruction error: 0.005611
# Epoch [364 / 500] average reconstruction error: 0.004419
# Epoch [365 / 500] average reconstruction error: 0.004975
# Epoch [366 / 500] average reconstruction error: 0.005079
# Epoch [367 / 500] average reconstruction error: 0.005665
# Epoch [368 / 500] average reconstruction error: 0.004989
# Epoch [369 / 500] average reconstruction error: 0.004810
# Epoch [370 / 500] average reconstruction error: 0.005269
# Epoch [371 / 500] average reconstruction error: 0.004863
# Epoch [372 / 500] average reconstruction error: 0.004505
# Epoch [373 / 500] average reconstruction error: 0.004912
# Epoch [374 / 500] average reconstruction error: 0.006031
# Epoch [375 / 500] average reconstruction error: 0.004927
# Epoch [376 / 500] average reconstruction error: 0.004643
# Epoch [377 / 500] average reconstruction error: 0.004407
# Epoch [378 / 500] average reconstruction error: 0.004633
# Epoch [379 / 500] average reconstruction error: 0.004539
# Epoch [380 / 500] average reconstruction error: 0.004383
# Epoch [381 / 500] average reconstruction error: 0.004222
# Epoch [382 / 500] average reconstruction error: 0.004260
# Epoch [383 / 500] average reconstruction error: 0.004153
# Epoch [384 / 500] average reconstruction error: 0.004645
# Epoch [385 / 500] average reconstruction error: 0.004185
# Epoch [386 / 500] average reconstruction error: 0.003961
# Epoch [387 / 500] average reconstruction error: 0.004781
# Epoch [388 / 500] average reconstruction error: 0.004417
# Epoch [389 / 500] average reconstruction error: 0.004076
# Epoch [390 / 500] average reconstruction error: 0.003738
# Epoch [391 / 500] average reconstruction error: 0.004072
# Epoch [392 / 500] average reconstruction error: 0.003566
# Epoch [393 / 500] average reconstruction error: 0.003828
# Epoch [394 / 500] average reconstruction error: 0.005233
# Epoch [395 / 500] average reconstruction error: 0.004659
# Epoch [396 / 500] average reconstruction error: 0.004036
# Epoch [397 / 500] average reconstruction error: 0.003770
# Epoch [398 / 500] average reconstruction error: 0.004609
# Epoch [399 / 500] average reconstruction error: 0.003729
# Epoch [400 / 500] average reconstruction error: 0.004173
# Epoch [401 / 500] average reconstruction error: 0.004106
# Epoch [402 / 500] average reconstruction error: 0.004451
# Epoch [403 / 500] average reconstruction error: 0.003632
# Epoch [404 / 500] average reconstruction error: 0.003544
# Epoch [405 / 500] average reconstruction error: 0.003443
# Epoch [406 / 500] average reconstruction error: 0.003417
# Epoch [407 / 500] average reconstruction error: 0.004072
# Epoch [408 / 500] average reconstruction error: 0.004273
# Epoch [409 / 500] average reconstruction error: 0.004188
# Epoch [410 / 500] average reconstruction error: 0.004107
# Epoch [411 / 500] average reconstruction error: 0.005537
# Epoch [412 / 500] average reconstruction error: 0.004501
# Epoch [413 / 500] average reconstruction error: 0.005129
# Epoch [414 / 500] average reconstruction error: 0.003608
# Epoch [415 / 500] average reconstruction error: 0.003866
# Epoch [416 / 500] average reconstruction error: 0.003779
# Epoch [417 / 500] average reconstruction error: 0.003924
# Epoch [418 / 500] average reconstruction error: 0.004418
# Epoch [419 / 500] average reconstruction error: 0.004012
# Epoch [420 / 500] average reconstruction error: 0.003196
# Epoch [421 / 500] average reconstruction error: 0.003196
# Epoch [422 / 500] average reconstruction error: 0.003619
# Epoch [423 / 500] average reconstruction error: 0.004123
# Epoch [424 / 500] average reconstruction error: 0.004044
# Epoch [425 / 500] average reconstruction error: 0.003551
# Epoch [426 / 500] average reconstruction error: 0.004325
# Epoch [427 / 500] average reconstruction error: 0.003338
# Epoch [428 / 500] average reconstruction error: 0.004491
# Epoch [429 / 500] average reconstruction error: 0.003684
# Epoch [430 / 500] average reconstruction error: 0.003319
# Epoch [431 / 500] average reconstruction error: 0.003226
# Epoch [432 / 500] average reconstruction error: 0.003607
# Epoch [433 / 500] average reconstruction error: 0.003879
# Epoch [434 / 500] average reconstruction error: 0.003653
# Epoch [435 / 500] average reconstruction error: 0.003266
# Epoch [436 / 500] average reconstruction error: 0.003301
# Epoch [437 / 500] average reconstruction error: 0.003460
# Epoch [438 / 500] average reconstruction error: 0.003769
# Epoch [439 / 500] average reconstruction error: 0.003004
# Epoch [440 / 500] average reconstruction error: 0.003129
# Epoch [441 / 500] average reconstruction error: 0.003606
# Epoch [442 / 500] average reconstruction error: 0.002693
# Epoch [443 / 500] average reconstruction error: 0.002805
# Epoch [444 / 500] average reconstruction error: 0.004480
# Epoch [445 / 500] average reconstruction error: 0.003570
# Epoch [446 / 500] average reconstruction error: 0.002819
# Epoch [447 / 500] average reconstruction error: 0.002541
# Epoch [448 / 500] average reconstruction error: 0.002886
# Epoch [449 / 500] average reconstruction error: 0.002659
# Epoch [450 / 500] average reconstruction error: 0.002947
# Epoch [451 / 500] average reconstruction error: 0.003029
# Epoch [452 / 500] average reconstruction error: 0.003193
# Epoch [453 / 500] average reconstruction error: 0.002324
# Epoch [454 / 500] average reconstruction error: 0.002662
# Epoch [455 / 500] average reconstruction error: 0.002730
# Epoch [456 / 500] average reconstruction error: 0.002772
# Epoch [457 / 500] average reconstruction error: 0.002796
# Epoch [458 / 500] average reconstruction error: 0.002782
# Epoch [459 / 500] average reconstruction error: 0.003006
# Epoch [460 / 500] average reconstruction error: 0.003190
# Epoch [461 / 500] average reconstruction error: 0.002531
# Epoch [462 / 500] average reconstruction error: 0.002390
# Epoch [463 / 500] average reconstruction error: 0.003352
# Epoch [464 / 500] average reconstruction error: 0.002275
# Epoch [465 / 500] average reconstruction error: 0.003516
# Epoch [466 / 500] average reconstruction error: 0.002101
# Epoch [467 / 500] average reconstruction error: 0.002314
# Epoch [468 / 500] average reconstruction error: 0.003061
# Epoch [469 / 500] average reconstruction error: 0.002601
# Epoch [470 / 500] average reconstruction error: 0.002279
# Epoch [471 / 500] average reconstruction error: 0.003084
# Epoch [472 / 500] average reconstruction error: 0.002794
# Epoch [473 / 500] average reconstruction error: 0.002239
# Epoch [474 / 500] average reconstruction error: 0.002508
# Epoch [475 / 500] average reconstruction error: 0.002211
# Epoch [476 / 500] average reconstruction error: 0.002493
# Epoch [477 / 500] average reconstruction error: 0.002160
# Epoch [478 / 500] average reconstruction error: 0.001901
# Epoch [479 / 500] average reconstruction error: 0.002189
# Epoch [480 / 500] average reconstruction error: 0.002902
# Epoch [481 / 500] average reconstruction error: 0.004390
# Epoch [482 / 500] average reconstruction error: 0.002632
# Epoch [483 / 500] average reconstruction error: 0.002770
# Epoch [484 / 500] average reconstruction error: 0.003309
# Epoch [485 / 500] average reconstruction error: 0.003265
# Epoch [486 / 500] average reconstruction error: 0.002946
# Epoch [487 / 500] average reconstruction error: 0.002467
# Epoch [488 / 500] average reconstruction error: 0.003019
# Epoch [489 / 500] average reconstruction error: 0.003216
# Epoch [490 / 500] average reconstruction error: 0.002371
# Epoch [491 / 500] average reconstruction error: 0.002708
# Epoch [492 / 500] average reconstruction error: 0.002349
# Epoch [493 / 500] average reconstruction error: 0.002463
# Epoch [494 / 500] average reconstruction error: 0.002431
# Epoch [495 / 500] average reconstruction error: 0.002481
# Epoch [496 / 500] average reconstruction error: 0.002904
# Epoch [497 / 500] average reconstruction error: 0.002230
# Epoch [498 / 500] average reconstruction error: 0.002770
# Epoch [499 / 500] average reconstruction error: 0.002971
# Epoch [500 / 500] average reconstruction error: 0.002665

# %% [markdown]
# # Affichage de la courbe de loss

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure(figsize=(15,5))
plt.subplot(111)
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Evolution de la loss')
plt.grid()
plt.show()

# %% [markdown]
# # Reconstruction

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

ae.eval()

# En entrée, l'image à reconstruire et le modèle utilisé pour la reconstruction

for i in [63,65,48,97,102,217]:
    images = train_db[i,:,:]
    # Affichage de l'image originale
    print(dict_r['file_name'][15])
    print('Image originale')

    plt.figure(i,figsize=(15,4))
    plt.subplot(1,2,1)
    plt.plot((images[0,:]), label='Original')
    plt.title('Loudness')
    plt.grid()
    plt.subplot(1,2,2)
    plt.plot(images[1,:], label='Original')  
    plt.grid()
    plt.title('Pitch')
  
    # Reconstruct and visualise the images using the vae
    print('VAE reconstruction:')
    images_recon = ae(torch.from_numpy(images).view(1,2,750).float())
    images_recon = images_recon.detach().numpy()
    plt.figure(i,figsize=(15,4))
    plt.subplot(1,2,1)
    plt.grid()
    plt.plot(images_recon[0,0,:], label='Reconstruit')
    plt.subplot(1,2,2)
    plt.plot(images_recon[0,1,:], label='Reconstruit')
    plt.grid()
    plt.show()
# Out:
# data_2\Vn-ord-ff-1c-_A#6.wav
# Image originale
# VAE reconstruction:
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# data_2\Vn-ord-ff-1c-_A#6.wav
# Image originale
# VAE reconstruction:
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# data_2\Vn-ord-ff-1c-_A#6.wav
# Image originale
# VAE reconstruction:
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# data_2\Vn-ord-ff-1c-_A#6.wav
# Image originale
# VAE reconstruction:
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# data_2\Vn-ord-ff-1c-_A#6.wav
# Image originale
# VAE reconstruction:
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# data_2\Vn-ord-ff-1c-_A#6.wav
# Image originale
# VAE reconstruction:
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# C:\Users\gabri\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ### DDSP pour écouter résultats

# %%
#DDSP sur la reconstruction
pitch = torch.from_numpy(images_recon[0,1,:]*MAX2).float().reshape(1, -1, 1)
loudness = torch.from_numpy(images_recon[0,0,:]*MAX1).float().reshape(1, -1, 1)

ddsp = torch.jit.load('ddsp_solordinario_pretrained.ts')

reconstruction_out = ddsp(pitch, loudness)

# %%
#DDSP sur l'original Original
pitch = torch.from_numpy(images[1,:]*MAX2).float().reshape(1, -1, 1)
loudness = torch.from_numpy(images[0,:]*MAX1).float().reshape(1, -1, 1)

ddsp = torch.jit.load('ddsp_solordinario_pretrained.ts')

reconstruction_in = ddsp(pitch, loudness)

# %%
#Ecouter les sons
import sounddevice as sd
sig = reconstruction_out[0,:,0]
sig = sig.detach().numpy()
sd.play(sig*0.5/np.max(sig), 16000)

# %%
#Sauvergarder valeurs de l'entrainement
torch.save(ae.state_dict(), 'Train_AEconv_solordinario')

# %%
#charger les valeurs
ae.load_state_dict(torch.load('Train_AEconv_solordinario'))
ae.eval()
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (conv1): Sequential(
#       (0): Conv1d(2, 2, kernel_size=(10,), stride=(2,), padding=(7,))
#       (1): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv2): Sequential(
#       (0): Conv1d(2, 4, kernel_size=(5,), stride=(2,), padding=(7,))
#       (1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv3): Sequential(
#       (0): Conv1d(4, 8, kernel_size=(5,), stride=(2,), padding=(2,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv4): Sequential(
#       (0): Conv1d(8, 16, kernel_size=(5,), stride=(2,), padding=(2,))
#       (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv5): Sequential(
#       (0): Conv1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (lin1): Linear(in_features=784, out_features=1024, bias=True)
#   )
#   (decoder): Decoder(
#     (lin1): Linear(in_features=1024, out_features=784, bias=True)
#     (conv5): Sequential(
#       (0): ConvTranspose1d(16, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv4): Sequential(
#       (0): ConvTranspose1d(16, 8, kernel_size=(5,), stride=(2,), padding=(2,))
#       (1): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv3): Sequential(
#       (0): ConvTranspose1d(8, 4, kernel_size=(5,), stride=(2,), padding=(2,), output_padding=(1,))
#       (1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv2): Sequential(
#       (0): ConvTranspose1d(4, 2, kernel_size=(5,), stride=(2,), padding=(7,), output_padding=(1,))
#       (1): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): Sequential(
#       (0): ConvTranspose1d(2, 2, kernel_size=(10,), stride=(2,), padding=(7,))
#       (1): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
# Out:
# 24000
