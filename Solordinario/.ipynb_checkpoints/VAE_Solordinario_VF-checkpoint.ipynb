# %%
# %matplotlib inline
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
###### Espace latent 2 dimensions

latent_dims = 64
num_epochs = 3000
batch_size = 25
capacity = 2
learning_rate = 5e-4
variational_beta = 5e-3
coefPitch=10.
coefLoudness=1.

# %% [markdown]
# # Chargement des données

# %%
# import os
import descriptors
import numpy as np

dict_r1 = np.load('data_dict.npy', allow_pickle=True).item()

train_db1 = np.zeros([len(dict_r1['env']),2,750])


i = 0
for sample in dict_r1['env']:
    train_db1[i,:,:] = sample
    i+=1

dict_r2 = np.load('data_dict_jerem_v1.npy', allow_pickle=True).item() #used for validation

train_db2 = np.zeros([len(dict_r2['env']),2,750])


i = 0
for sample in dict_r2['env']:
    train_db2[i,:,:] = sample
    i+=1
#
 
#train_db = np.concatenate((train_db1, train_db2)) 
#train_db = np.concatenate((train_db1, train_db2))
train_db = train_db1

#train_db[:,1,:] = np.log10(train_db[:,1,:])
pitches = np.mean(train_db[:,1,:], axis=1)
pitches = np.expand_dims(pitches, axis=1)
pitches = np.broadcast_to(pitches,(252,750))

train_db[:,1,:] = train_db[:,1,:]/pitches[:] #on retire le pitch

MAX1 = np.max(np.abs(train_db[:,0,:]))
MAX2 = np.max(np.abs(train_db[:,1,:]))
train_db[:,0,:] /= MAX1
#train_db[:,1,:] /= MAX2
train_dataset =  torch.utils.data.TensorDataset(torch.from_numpy(train_db))

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, drop_last = True)
test_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=True, drop_last = True)

# %%
np.min(train_db[:,1,:])
# Out:
# 0.42202366990136636

# %% [markdown]
# # Defintion du AE
#
# Kernel Size = 4 papier qui explique pourquoi: https://distill.pub/2016/deconv-checkerboard/

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity     
        self.conv1 = nn.Sequential(nn.Conv1d(in_channels=2, out_channels=c, kernel_size=10, stride=2, padding=2), nn.BatchNorm1d(c)) # out: c, 372
        self.conv2 = nn.Sequential(nn.Conv1d(in_channels=c, out_channels=c*2, kernel_size=5, stride=2, padding=2), nn.BatchNorm1d(2*c)) # out: c*2, 186
        self.conv3 = nn.Sequential(nn.Conv1d(in_channels=c*2, out_channels=c*4, kernel_size=5, stride=2, padding=2), nn.BatchNorm1d(4*c)) # out: c*2, 186
        self.conv4 = nn.Sequential(nn.Conv1d(in_channels=c*4, out_channels=c*8, kernel_size=5, stride=2, padding=2), nn.BatchNorm1d(8*c)) # out: c*2, 186
        self.conv5 = nn.Sequential(nn.Conv1d(in_channels=c*8, out_channels=c*8, kernel_size=5, stride=1, padding=2), nn.BatchNorm1d(8*c)) # out: c*2, 186
        self.lin1 = nn.Linear(8*c*47, latent_dims*8)
        self.lin2 = nn.Linear(latent_dims*8, latent_dims*4)
        self.fc_mu = nn.Linear(in_features=latent_dims*4, out_features=latent_dims)
        self.fc_logvar = nn.Linear(in_features=latent_dims*4, out_features=latent_dims)
       
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = x.view(x.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=latent_dims*4)
        self.lin2 = nn.Linear(latent_dims*4, latent_dims*8)
        self.lin3 = nn.Linear(latent_dims*8, 8*c*47)
        self.lin4 = nn.Linear(in_features=750, out_features=750)
        self.conv1 = nn.Sequential(nn.Conv1d(in_channels=c*8, out_channels=c*8, kernel_size=5, stride=1, padding=2), nn.BatchNorm1d(8*c))
        self.conv2 = nn.Sequential(nn.Conv1d(in_channels=c*8, out_channels=c*4, kernel_size=5, stride=1, padding=2), nn.BatchNorm1d(4*c)) # out: c*2, 186
        self.conv3 = nn.Sequential(nn.Conv1d(in_channels=c*4, out_channels=c*2, kernel_size=5, stride=1, padding=2), nn.BatchNorm1d(2*c)) # out: c*2, 186
        self.conv4 = nn.Sequential(nn.Conv1d(in_channels=c*2, out_channels=c, kernel_size=5, stride=1, padding=2), nn.BatchNorm1d(c)) # out: c*2, 186
        self.conv5 = nn.Sequential(nn.Conv1d(in_channels=c, out_channels=2, kernel_size=10, stride=1, padding=4)) # out: c, 372
        self.conv6 = nn.Sequential(nn.Conv1d(in_channels=2, out_channels=2, kernel_size=10, stride=1, padding=4)) # out: c, 372
        self.upsample1 = nn.Upsample(scale_factor=2, mode="nearest")
        self.upsamplef = nn.Upsample(size=752, mode="nearest")

            
    def forward(self, x):
        x = F.relu(self.fc(x))
        x = F.relu(self.lin2(x))
        x = F.relu(self.lin3(x))
        x = x.view(x.size(0), capacity*8, 47) # unflatten batch of feature vectors to a batch of multi-channel feature maps
        x = F.relu(self.conv1(x))
        x = self.upsample1(x)
        x = F.relu(self.conv2(x))
        x = self.upsample1(x)
        x = F.relu(self.conv3(x))
        x = self.upsample1(x)
        x = F.relu(self.conv4(x))
        x = self.upsamplef(x)
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = torch.sigmoid(self.lin4(x)) # last layer before output is sigmoid, since we are using BCE as reconstruction loss
        return x
        
class VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            # the reparameterization trick
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu
    
def vae_loss(recon_x, x, mu, logvar):
    recon_loss = (coefLoudness*F.mse_loss(recon_x[:,0,:], x[:,0,:], reduction='sum')+coefPitch*F.mse_loss(recon_x[:,1,:], x[:,1,:], reduction='sum'))/np.size(batch_size)
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())/np.size(batch_size)  
    return recon_loss + variational_beta * kldivergence, recon_loss, variational_beta * kldivergence
    
vae = VariationalAutoencoder()

num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 1651602

# %% [markdown]
# # Entrainement

# %%
optimizer = torch.optim.Adam(params=vae.parameters(), lr=learning_rate, weight_decay=1e-5)

# set to training mode
vae.train()

train_loss_avg = []
train_loss_avg2 = []
train_loss_avg3 = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    train_loss_avg2.append(0)
    train_loss_avg3.append(0)
    num_batches = 0
    
    for image_batch in train_loader:

        #image_batch = image_batch.to(device)
        image_batch = torch.DoubleTensor(image_batch[0])
        image_batch = image_batch.view(batch_size,2,750)
        
        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch.float())
        
        # reconstruction error
        loss, loss2, loss3 = vae_loss(image_batch_recon, image_batch.float(), latent_mu, latent_logvar)
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        
        # one step of the optmizer (using the gradients from backpropagation)
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()
        train_loss_avg2[-1] += loss2.item()
        train_loss_avg3[-1] += loss3.item()
        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    train_loss_avg2[-1] /= num_batches
    train_loss_avg3[-1] /= num_batches
    
    if epoch%20 == 19:
        print('Epoch [%d / %d] average reconstruction error: %f (l2 = %f, l3 = %f)' % (epoch+1, num_epochs, train_loss_avg[-1], train_loss_avg2[-1], train_loss_avg3[-1]))
# Out:
# Training ...
# Epoch [20 / 3000] average reconstruction error: 42623.048438 (l2 = 42620.291016, l3 = 2.757621)
# Epoch [40 / 3000] average reconstruction error: 38451.592969 (l2 = 38449.267578, l3 = 2.325336)
# Epoch [60 / 3000] average reconstruction error: 34640.590234 (l2 = 34638.486328, l3 = 2.104087)
# Epoch [80 / 3000] average reconstruction error: 31183.477930 (l2 = 31181.371680, l3 = 2.106350)
# Epoch [100 / 3000] average reconstruction error: 28054.667578 (l2 = 28052.828125, l3 = 1.839518)
# Epoch [120 / 3000] average reconstruction error: 25239.933789 (l2 = 25238.313477, l3 = 1.620244)
# Epoch [140 / 3000] average reconstruction error: 22714.599609 (l2 = 22713.087891, l3 = 1.511645)
# Epoch [160 / 3000] average reconstruction error: 20451.250781 (l2 = 20449.876367, l3 = 1.374214)
# Epoch [180 / 3000] average reconstruction error: 18425.380273 (l2 = 18423.840234, l3 = 1.539875)
# Epoch [200 / 3000] average reconstruction error: 16605.223047 (l2 = 16603.673828, l3 = 1.549183)
# Epoch [220 / 3000] average reconstruction error: 14986.143945 (l2 = 14984.521094, l3 = 1.622941)
# Epoch [240 / 3000] average reconstruction error: 13529.439648 (l2 = 13527.794043, l3 = 1.645629)
# Epoch [260 / 3000] average reconstruction error: 12236.736816 (l2 = 12235.108887, l3 = 1.628022)
# Epoch [280 / 3000] average reconstruction error: 11069.491406 (l2 = 11067.826270, l3 = 1.665065)
# Epoch [300 / 3000] average reconstruction error: 10029.624707 (l2 = 10027.904590, l3 = 1.719955)
# Epoch [320 / 3000] average reconstruction error: 9093.447168 (l2 = 9091.674805, l3 = 1.772276)
# Epoch [340 / 3000] average reconstruction error: 8245.379150 (l2 = 8243.883057, l3 = 1.496179)
# Epoch [360 / 3000] average reconstruction error: 7498.371191 (l2 = 7496.901709, l3 = 1.469444)
# Epoch [380 / 3000] average reconstruction error: 6818.893115 (l2 = 6817.395410, l3 = 1.497715)
# Epoch [400 / 3000] average reconstruction error: 6203.017627 (l2 = 6201.562012, l3 = 1.455696)
# Epoch [420 / 3000] average reconstruction error: 5654.220850 (l2 = 5652.820117, l3 = 1.400669)
# Epoch [440 / 3000] average reconstruction error: 5155.536523 (l2 = 5154.099414, l3 = 1.437214)
# Epoch [460 / 3000] average reconstruction error: 4706.011670 (l2 = 4704.599268, l3 = 1.412427)
# Epoch [480 / 3000] average reconstruction error: 4287.668506 (l2 = 4286.280127, l3 = 1.388481)
# Epoch [500 / 3000] average reconstruction error: 3929.637988 (l2 = 3928.193726, l3 = 1.444251)
# Epoch [520 / 3000] average reconstruction error: 3596.426001 (l2 = 3595.067480, l3 = 1.358564)
# Epoch [540 / 3000] average reconstruction error: 3290.872046 (l2 = 3289.471240, l3 = 1.400797)
# Epoch [560 / 3000] average reconstruction error: 3017.631274 (l2 = 3016.311328, l3 = 1.319985)
# Epoch [580 / 3000] average reconstruction error: 2767.513696 (l2 = 2766.143188, l3 = 1.370517)
# Epoch [600 / 3000] average reconstruction error: 2540.311523 (l2 = 2538.967847, l3 = 1.343642)
# Epoch [620 / 3000] average reconstruction error: 2336.076904 (l2 = 2334.673633, l3 = 1.403273)
# Epoch [640 / 3000] average reconstruction error: 2146.846948 (l2 = 2145.421997, l3 = 1.424990)
# Epoch [660 / 3000] average reconstruction error: 1968.589319 (l2 = 1967.211951, l3 = 1.377365)
# Epoch [680 / 3000] average reconstruction error: 1815.407166 (l2 = 1814.009216, l3 = 1.397964)
# Epoch [700 / 3000] average reconstruction error: 1676.387549 (l2 = 1675.042566, l3 = 1.344997)
# Epoch [720 / 3000] average reconstruction error: 1546.788184 (l2 = 1545.394226, l3 = 1.393965)
# Epoch [740 / 3000] average reconstruction error: 1428.065454 (l2 = 1426.737500, l3 = 1.327958)
# Epoch [760 / 3000] average reconstruction error: 1321.217896 (l2 = 1319.851697, l3 = 1.366215)
# Epoch [780 / 3000] average reconstruction error: 1221.465503 (l2 = 1220.084412, l3 = 1.381073)
# Epoch [800 / 3000] average reconstruction error: 1125.499908 (l2 = 1124.136188, l3 = 1.363733)
# Epoch [820 / 3000] average reconstruction error: 1042.954053 (l2 = 1041.594202, l3 = 1.359856)
# Epoch [840 / 3000] average reconstruction error: 965.955762 (l2 = 964.573834, l3 = 1.381930)
# Epoch [860 / 3000] average reconstruction error: 900.905884 (l2 = 899.506641, l3 = 1.399244)
# Epoch [880 / 3000] average reconstruction error: 833.500861 (l2 = 832.035828, l3 = 1.465036)
# Epoch [900 / 3000] average reconstruction error: 784.043744 (l2 = 782.614307, l3 = 1.429442)
# Epoch [920 / 3000] average reconstruction error: 730.408063 (l2 = 728.971301, l3 = 1.436772)
# Epoch [940 / 3000] average reconstruction error: 682.389691 (l2 = 681.021411, l3 = 1.368276)
# Epoch [960 / 3000] average reconstruction error: 640.489807 (l2 = 639.087701, l3 = 1.402113)
# Epoch [980 / 3000] average reconstruction error: 600.563675 (l2 = 599.126794, l3 = 1.436884)
# Epoch [1000 / 3000] average reconstruction error: 559.995206 (l2 = 558.605963, l3 = 1.389244)
# Epoch [1020 / 3000] average reconstruction error: 525.676889 (l2 = 524.294785, l3 = 1.382108)
# Epoch [1040 / 3000] average reconstruction error: 496.628668 (l2 = 495.234088, l3 = 1.394580)
# Epoch [1060 / 3000] average reconstruction error: 466.033890 (l2 = 464.672806, l3 = 1.361080)
# Epoch [1080 / 3000] average reconstruction error: 440.747684 (l2 = 439.363406, l3 = 1.384277)
# Epoch [1100 / 3000] average reconstruction error: 411.285406 (l2 = 409.908179, l3 = 1.377225)
# Epoch [1120 / 3000] average reconstruction error: 392.395651 (l2 = 391.001492, l3 = 1.394156)
# Epoch [1140 / 3000] average reconstruction error: 374.096240 (l2 = 372.664005, l3 = 1.432227)
# Epoch [1160 / 3000] average reconstruction error: 354.441542 (l2 = 353.029005, l3 = 1.412539)
# Epoch [1180 / 3000] average reconstruction error: 337.754669 (l2 = 336.342876, l3 = 1.411798)
# Epoch [1200 / 3000] average reconstruction error: 319.290259 (l2 = 317.935368, l3 = 1.354893)
# Epoch [1220 / 3000] average reconstruction error: 306.989912 (l2 = 305.584738, l3 = 1.405178)
# Epoch [1240 / 3000] average reconstruction error: 292.287495 (l2 = 290.888472, l3 = 1.399019)
# Epoch [1260 / 3000] average reconstruction error: 282.216266 (l2 = 280.829845, l3 = 1.386421)
# Epoch [1280 / 3000] average reconstruction error: 270.819798 (l2 = 269.416225, l3 = 1.403575)
# Epoch [1300 / 3000] average reconstruction error: 259.891833 (l2 = 258.534329, l3 = 1.357504)
# Epoch [1320 / 3000] average reconstruction error: 251.392409 (l2 = 249.913579, l3 = 1.478828)
# Epoch [1340 / 3000] average reconstruction error: 241.921215 (l2 = 240.569434, l3 = 1.351781)
# Epoch [1360 / 3000] average reconstruction error: 234.947621 (l2 = 233.564325, l3 = 1.383297)
# Epoch [1380 / 3000] average reconstruction error: 227.347038 (l2 = 225.926707, l3 = 1.420330)
# Epoch [1400 / 3000] average reconstruction error: 220.136795 (l2 = 218.739956, l3 = 1.396842)
# Epoch [1420 / 3000] average reconstruction error: 214.157796 (l2 = 212.769392, l3 = 1.388403)
# Epoch [1440 / 3000] average reconstruction error: 209.524780 (l2 = 208.090572, l3 = 1.434208)
# Epoch [1460 / 3000] average reconstruction error: 203.294447 (l2 = 201.934252, l3 = 1.360194)
# Epoch [1480 / 3000] average reconstruction error: 199.171244 (l2 = 197.751234, l3 = 1.420008)
# Epoch [1500 / 3000] average reconstruction error: 194.485661 (l2 = 193.154043, l3 = 1.331621)
# Epoch [1520 / 3000] average reconstruction error: 190.575327 (l2 = 189.183962, l3 = 1.391362)
# Epoch [1540 / 3000] average reconstruction error: 187.189994 (l2 = 185.755059, l3 = 1.434937)
# Epoch [1560 / 3000] average reconstruction error: 182.953712 (l2 = 181.572972, l3 = 1.380739)
# Epoch [1580 / 3000] average reconstruction error: 180.906839 (l2 = 179.479108, l3 = 1.427732)
# Epoch [1600 / 3000] average reconstruction error: 177.493180 (l2 = 176.038483, l3 = 1.454695)
# Epoch [1620 / 3000] average reconstruction error: 175.683450 (l2 = 174.234220, l3 = 1.449228)
# Epoch [1640 / 3000] average reconstruction error: 172.337336 (l2 = 170.934265, l3 = 1.403070)
# Epoch [1660 / 3000] average reconstruction error: 169.875651 (l2 = 168.455678, l3 = 1.419972)
# Epoch [1680 / 3000] average reconstruction error: 168.388180 (l2 = 166.995350, l3 = 1.392832)
# Epoch [1700 / 3000] average reconstruction error: 168.881526 (l2 = 167.411066, l3 = 1.470461)
# Epoch [1720 / 3000] average reconstruction error: 164.800889 (l2 = 163.384349, l3 = 1.416539)
# Epoch [1740 / 3000] average reconstruction error: 153.054823 (l2 = 151.590075, l3 = 1.464745)
# Epoch [1760 / 3000] average reconstruction error: 160.506696 (l2 = 159.097966, l3 = 1.408731)
# Epoch [1780 / 3000] average reconstruction error: 160.287894 (l2 = 158.862895, l3 = 1.424999)
# Epoch [1800 / 3000] average reconstruction error: 153.504678 (l2 = 152.122882, l3 = 1.381796)
# Epoch [1820 / 3000] average reconstruction error: 158.582567 (l2 = 157.172946, l3 = 1.409620)
# Epoch [1840 / 3000] average reconstruction error: 156.359772 (l2 = 154.953325, l3 = 1.406450)
# Epoch [1860 / 3000] average reconstruction error: 150.703753 (l2 = 149.293509, l3 = 1.410244)
# Epoch [1880 / 3000] average reconstruction error: 155.264605 (l2 = 153.802021, l3 = 1.462584)
# Epoch [1900 / 3000] average reconstruction error: 154.514504 (l2 = 153.093250, l3 = 1.421257)
# Epoch [1920 / 3000] average reconstruction error: 154.636312 (l2 = 153.214694, l3 = 1.421616)
# Epoch [1940 / 3000] average reconstruction error: 153.054727 (l2 = 151.652498, l3 = 1.402230)
# Epoch [1960 / 3000] average reconstruction error: 152.739412 (l2 = 151.343239, l3 = 1.396174)
# Epoch [1980 / 3000] average reconstruction error: 152.903609 (l2 = 151.475535, l3 = 1.428073)
# Epoch [2000 / 3000] average reconstruction error: 150.670052 (l2 = 149.251846, l3 = 1.418206)
# Epoch [2020 / 3000] average reconstruction error: 151.044270 (l2 = 149.591558, l3 = 1.452712)
# Epoch [2040 / 3000] average reconstruction error: 151.035428 (l2 = 149.675642, l3 = 1.359786)
# Epoch [2060 / 3000] average reconstruction error: 150.040334 (l2 = 148.608307, l3 = 1.432027)
# Epoch [2080 / 3000] average reconstruction error: 140.907659 (l2 = 139.478970, l3 = 1.428691)
# Epoch [2100 / 3000] average reconstruction error: 143.269721 (l2 = 141.922704, l3 = 1.347017)
# Epoch [2120 / 3000] average reconstruction error: 150.232885 (l2 = 148.795235, l3 = 1.437650)
# Epoch [2140 / 3000] average reconstruction error: 149.382175 (l2 = 147.986144, l3 = 1.396032)
# Epoch [2160 / 3000] average reconstruction error: 148.876808 (l2 = 147.482734, l3 = 1.394073)
# Epoch [2180 / 3000] average reconstruction error: 147.996058 (l2 = 146.580894, l3 = 1.415162)
# Epoch [2200 / 3000] average reconstruction error: 147.933482 (l2 = 146.568350, l3 = 1.365131)
# Epoch [2220 / 3000] average reconstruction error: 148.227203 (l2 = 146.826586, l3 = 1.400616)
# Epoch [2240 / 3000] average reconstruction error: 138.273390 (l2 = 136.890134, l3 = 1.383257)
# Epoch [2260 / 3000] average reconstruction error: 147.499557 (l2 = 146.092017, l3 = 1.407540)
# Epoch [2280 / 3000] average reconstruction error: 147.190321 (l2 = 145.780869, l3 = 1.409452)
# Epoch [2300 / 3000] average reconstruction error: 137.561049 (l2 = 136.137948, l3 = 1.423102)
# Epoch [2320 / 3000] average reconstruction error: 147.934755 (l2 = 146.560135, l3 = 1.374620)
# Epoch [2340 / 3000] average reconstruction error: 147.322013 (l2 = 145.920620, l3 = 1.401392)
# Epoch [2360 / 3000] average reconstruction error: 146.989735 (l2 = 145.588939, l3 = 1.400796)
# Epoch [2380 / 3000] average reconstruction error: 146.065530 (l2 = 144.662351, l3 = 1.403179)
# Epoch [2400 / 3000] average reconstruction error: 145.270606 (l2 = 143.824801, l3 = 1.445803)
# Epoch [2420 / 3000] average reconstruction error: 146.973283 (l2 = 145.574851, l3 = 1.398431)
# Epoch [2440 / 3000] average reconstruction error: 144.353586 (l2 = 142.973273, l3 = 1.380316)
# Epoch [2460 / 3000] average reconstruction error: 145.765706 (l2 = 144.380358, l3 = 1.385347)
# Epoch [2480 / 3000] average reconstruction error: 145.798112 (l2 = 144.389200, l3 = 1.408913)
# Epoch [2500 / 3000] average reconstruction error: 146.024618 (l2 = 144.611925, l3 = 1.412695)
# Epoch [2520 / 3000] average reconstruction error: 146.082102 (l2 = 144.683771, l3 = 1.398331)
# Epoch [2540 / 3000] average reconstruction error: 145.898475 (l2 = 144.559616, l3 = 1.338856)
# Epoch [2560 / 3000] average reconstruction error: 136.321229 (l2 = 134.885332, l3 = 1.435897)
# Epoch [2580 / 3000] average reconstruction error: 146.191871 (l2 = 144.771213, l3 = 1.420659)
# Epoch [2600 / 3000] average reconstruction error: 145.901582 (l2 = 144.485665, l3 = 1.415918)
# Epoch [2620 / 3000] average reconstruction error: 145.545264 (l2 = 144.113224, l3 = 1.432038)
# Epoch [2640 / 3000] average reconstruction error: 142.779265 (l2 = 141.422431, l3 = 1.356834)
# Epoch [2660 / 3000] average reconstruction error: 146.469644 (l2 = 145.020742, l3 = 1.448903)
# Epoch [2680 / 3000] average reconstruction error: 140.404932 (l2 = 138.984022, l3 = 1.420911)
# Epoch [2700 / 3000] average reconstruction error: 131.486240 (l2 = 130.052963, l3 = 1.433274)
# Epoch [2720 / 3000] average reconstruction error: 145.034454 (l2 = 143.686722, l3 = 1.347732)
# Epoch [2740 / 3000] average reconstruction error: 145.546655 (l2 = 144.155175, l3 = 1.391483)
# Epoch [2760 / 3000] average reconstruction error: 144.880379 (l2 = 143.492313, l3 = 1.388066)
# Epoch [2780 / 3000] average reconstruction error: 144.063545 (l2 = 142.619879, l3 = 1.443669)
# Epoch [2800 / 3000] average reconstruction error: 144.558725 (l2 = 143.172846, l3 = 1.385877)
# Epoch [2820 / 3000] average reconstruction error: 144.759105 (l2 = 143.375984, l3 = 1.383120)
# Epoch [2840 / 3000] average reconstruction error: 144.523324 (l2 = 143.125478, l3 = 1.397846)
# Epoch [2860 / 3000] average reconstruction error: 144.494470 (l2 = 143.134252, l3 = 1.360217)
# Epoch [2880 / 3000] average reconstruction error: 144.704801 (l2 = 143.375340, l3 = 1.329462)
# Epoch [2900 / 3000] average reconstruction error: 145.382438 (l2 = 143.948643, l3 = 1.433793)
# Epoch [2920 / 3000] average reconstruction error: 143.022681 (l2 = 141.655574, l3 = 1.367109)
# Epoch [2940 / 3000] average reconstruction error: 145.851460 (l2 = 144.427613, l3 = 1.423849)
# Epoch [2960 / 3000] average reconstruction error: 146.018803 (l2 = 144.527679, l3 = 1.491121)
# Epoch [2980 / 3000] average reconstruction error: 142.964457 (l2 = 141.639677, l3 = 1.324780)
# Epoch [3000 / 3000] average reconstruction error: 141.454366 (l2 = 140.067104, l3 = 1.387260)

# %% [markdown]
# # Affichage de la courbe de loss

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure(figsize=(20,8))
plt.subplot(211)
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Evolution Loss + KLdiv')
plt.grid()
plt.subplot(223)
plt.plot(train_loss_avg2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Evolution Loss')
plt.grid()
plt.subplot(224)
plt.plot(train_loss_avg3)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Evolution KLdiv')
plt.grid()
plt.show()

# %% [markdown]
# # Reconstruction

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

# En entrée, l'image à reconstruire et le modèle utilisé pour la reconstruction

index_list = [10,20,30,40,50,60]
index_list = list(range(12))

list_sources = [[train_db[i,0,:],train_db[i,1,:]*pitches[i]] for i in index_list]

list_images = []
for i in index_list:
    images = train_db[i,:,:]
    images_recon,_,_ = vae(torch.from_numpy(images).view(1,2,750).float())
    images_recon = images_recon.detach().numpy()
    list_images.append([images_recon[0,0,:],(images_recon[0,1,:]*(pitches[i]))])

# %% [markdown]
# ## Visualisation :

# %%
from visualizer import Visualizer
V = Visualizer(list_images,list_sources)

# %%
V.show_pitch()
V.show_loudness()

# %%
torch.save(vae.state_dict(), "vaeMODELtrained2")

# %% [markdown]
# ### DDSP pour écouter résultats

# %%
ddsp = torch.jit.load('ddsp_solordinario_pretrained.ts')
V.reconstruction(ddsp)
V.show_sound()
V.show_spectrogramm()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Écoute des sons obtenus :

# %%
V.listen(5)

# %%
MAX2
# Out:
# 0.3728937852515122
