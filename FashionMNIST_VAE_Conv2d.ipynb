# %%
# %matplotlib inline
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# %%
# Espace latent 2 dimensions

latent_dims = 2
num_epochs = 100
batch_size = 128
capacity = 64
learning_rate = 1e-3
variational_beta = 1
use_gpu = True



# # 10-d Espace latent en 10 dimensions, qui correspond à un Autoencoder simple (à comparer avec le VAE 
# et un espace latent de 2 dimensions)
# latent_dims = 10
# num_epochs = 100
# batch_size = 128
# capacity = 64
# learning_rate = 1e-3
# variational_beta = 1
# use_gpu = True

# %% [markdown]
# # Chargement des données

# %%
img_transform = transforms.Compose([
    transforms.ToTensor()
])

train_dataset = FashionMNIST(root='./data/F_MNIST_data', download=True, train=True, transform=img_transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = FashionMNIST(root='./data/F_MNIST_data', download=True, train=False, transform=img_transform)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Defintion du VAE
#
# Kernel Size = 4 papier qui explique pourquoi: https://distill.pub/2016/deconv-checkerboard/

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=c, kernel_size=4, stride=2, padding=1) # out: c x 14 x 14
        self.conv2 = nn.Conv2d(in_channels=c, out_channels=c*2, kernel_size=4, stride=2, padding=1) # out: c x 7 x 7
        self.fc_mu = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
        self.fc_logvar = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
            
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=c*2*7*7)
        self.conv2 = nn.ConvTranspose2d(in_channels=c*2, out_channels=c, kernel_size=4, stride=2, padding=1)
        self.conv1 = nn.ConvTranspose2d(in_channels=c, out_channels=1, kernel_size=4, stride=2, padding=1)
            
    def forward(self, x):
        x = self.fc(x)
        x = x.view(x.size(0), capacity*2, 7, 7) # unflatten batch of feature vectors to a batch of multi-channel feature maps
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv1(x)) # last layer before output is sigmoid, since we are using BCE as reconstruction loss
        return x
    
class VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar
    
    def latent_sample(self, mu, logvar):
        if self.training:
            # the reparameterization trick
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu
    
def vae_loss(recon_x, x, mu, logvar):
    # recon_x is the probability of a multivariate Bernoulli distribution p.
    # -log(p(x)) is then the pixel-wise binary cross-entropy.
    # Averaging or not averaging the binary cross-entropy over all pixels here
    # is a subtle detail with big effect on training, since it changes the weight
    # we need to pick for the other loss term by several orders of magnitude.
    # Not averaging is the direct implementation of the negative log likelihood,
    # but averaging makes the weight of the other loss term independent of the image resolution.
    recon_loss = F.binary_cross_entropy(recon_x.view(-1, 784), x.view(-1, 784), reduction='sum')
    
    # KL-divergence between the prior distribution over latent vectors
    # (the one we are going to sample from when generating new images)
    # and the distribution estimated by the generator for the given image.
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return recon_loss + variational_beta * kldivergence
    
    
vae = VariationalAutoencoder()

device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")
vae = vae.to(device)

num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 308357

# %% [markdown]
# # Entrainement

# %%
optimizer = torch.optim.Adam(params=vae.parameters(), lr=learning_rate, weight_decay=1e-5)

# set to training mode
vae.train()

train_loss_avg = []

print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    
    for image_batch, _ in train_dataloader:
        
        image_batch = image_batch.to(device)

        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)
        
        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)
        
        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        # one step of the optmizer (using the gradients from backpropagation)
        optimizer.step()
        
        train_loss_avg[-1] += loss.item()
        num_batches += 1
        
    train_loss_avg[-1] /= num_batches
    print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
# Out:
# Training ...
# Epoch [1 / 100] average reconstruction error: 36738.043040
# Epoch [2 / 100] average reconstruction error: 34658.704999
# Epoch [3 / 100] average reconstruction error: 34348.488619
# Epoch [4 / 100] average reconstruction error: 34176.381717
# Epoch [5 / 100] average reconstruction error: 34030.406417
# Epoch [6 / 100] average reconstruction error: 33939.607568
# Epoch [7 / 100] average reconstruction error: 33862.913525
# Epoch [8 / 100] average reconstruction error: 33809.943343
# Epoch [9 / 100] average reconstruction error: 33759.395664
# Epoch [10 / 100] average reconstruction error: 33700.220187
# Epoch [11 / 100] average reconstruction error: 33679.322882
# Epoch [12 / 100] average reconstruction error: 33625.665033
# Epoch [13 / 100] average reconstruction error: 33599.750100
# Epoch [14 / 100] average reconstruction error: 33561.589523
# Epoch [15 / 100] average reconstruction error: 33542.727008
# Epoch [16 / 100] average reconstruction error: 33515.380926
# Epoch [17 / 100] average reconstruction error: 33487.539067
# Epoch [18 / 100] average reconstruction error: 33464.904064
# Epoch [19 / 100] average reconstruction error: 33443.527394
# Epoch [20 / 100] average reconstruction error: 33425.818530
# Epoch [21 / 100] average reconstruction error: 33406.098410
# Epoch [22 / 100] average reconstruction error: 33386.403889
# Epoch [23 / 100] average reconstruction error: 33364.761265
# Epoch [24 / 100] average reconstruction error: 33351.593438
# Epoch [25 / 100] average reconstruction error: 33337.170342
# Epoch [26 / 100] average reconstruction error: 33315.955116
# Epoch [27 / 100] average reconstruction error: 33301.831432
# Epoch [28 / 100] average reconstruction error: 33282.508924
# Epoch [29 / 100] average reconstruction error: 33278.331848
# Epoch [30 / 100] average reconstruction error: 33253.224759
# Epoch [31 / 100] average reconstruction error: 33244.163134
# Epoch [32 / 100] average reconstruction error: 33239.225222
# Epoch [33 / 100] average reconstruction error: 33226.982572
# Epoch [34 / 100] average reconstruction error: 33225.814037
# Epoch [35 / 100] average reconstruction error: 33200.363614
# Epoch [36 / 100] average reconstruction error: 33189.798828
# Epoch [37 / 100] average reconstruction error: 33184.540345
# Epoch [38 / 100] average reconstruction error: 33183.454304
# Epoch [39 / 100] average reconstruction error: 33167.936667
# Epoch [40 / 100] average reconstruction error: 33155.138539
# Epoch [41 / 100] average reconstruction error: 33156.951772
# Epoch [42 / 100] average reconstruction error: 33141.315361
# Epoch [43 / 100] average reconstruction error: 33124.564486
# Epoch [44 / 100] average reconstruction error: 33114.058719
# Epoch [45 / 100] average reconstruction error: 33122.991155
# Epoch [46 / 100] average reconstruction error: 33117.352225
# Epoch [47 / 100] average reconstruction error: 33106.584842
# Epoch [48 / 100] average reconstruction error: 33080.666761
# Epoch [49 / 100] average reconstruction error: 33088.453858
# Epoch [50 / 100] average reconstruction error: 33075.137806
# Epoch [51 / 100] average reconstruction error: 33073.784198
# Epoch [52 / 100] average reconstruction error: 33061.532745
# Epoch [53 / 100] average reconstruction error: 33050.892711
# Epoch [54 / 100] average reconstruction error: 33056.305287
# Epoch [55 / 100] average reconstruction error: 33041.433923
# Epoch [56 / 100] average reconstruction error: 33045.227674
# Epoch [57 / 100] average reconstruction error: 33032.921338
# Epoch [58 / 100] average reconstruction error: 33027.465989
# Epoch [59 / 100] average reconstruction error: 33023.654747
# Epoch [60 / 100] average reconstruction error: 33016.437171
# Epoch [61 / 100] average reconstruction error: 33016.536743
# Epoch [62 / 100] average reconstruction error: 33016.232239
# Epoch [63 / 100] average reconstruction error: 33005.391191
# Epoch [64 / 100] average reconstruction error: 32996.946233
# Epoch [65 / 100] average reconstruction error: 32990.547358
# Epoch [66 / 100] average reconstruction error: 32986.986436
# Epoch [67 / 100] average reconstruction error: 32986.591305
# Epoch [68 / 100] average reconstruction error: 32973.621319
# Epoch [69 / 100] average reconstruction error: 32977.428605
# Epoch [70 / 100] average reconstruction error: 32972.300315
# Epoch [71 / 100] average reconstruction error: 32963.531450
# Epoch [72 / 100] average reconstruction error: 32957.793981
# Epoch [73 / 100] average reconstruction error: 32957.140096
# Epoch [74 / 100] average reconstruction error: 32946.132488
# Epoch [75 / 100] average reconstruction error: 32942.377036
# Epoch [76 / 100] average reconstruction error: 32935.703883
# Epoch [77 / 100] average reconstruction error: 32936.166607
# Epoch [78 / 100] average reconstruction error: 32929.629102
# Epoch [79 / 100] average reconstruction error: 32933.036164
# Epoch [80 / 100] average reconstruction error: 32925.032337
# Epoch [81 / 100] average reconstruction error: 32926.421442
# Epoch [82 / 100] average reconstruction error: 32923.412147
# Epoch [83 / 100] average reconstruction error: 32915.087353
# Epoch [84 / 100] average reconstruction error: 32910.452513
# Epoch [85 / 100] average reconstruction error: 32902.474664
# Epoch [86 / 100] average reconstruction error: 32913.138364
# Epoch [87 / 100] average reconstruction error: 32894.894581
# Epoch [88 / 100] average reconstruction error: 32897.714544
# Epoch [89 / 100] average reconstruction error: 32886.979927
# Epoch [90 / 100] average reconstruction error: 32883.271047
# Epoch [91 / 100] average reconstruction error: 32891.968663
# Epoch [92 / 100] average reconstruction error: 32884.066127
# Epoch [93 / 100] average reconstruction error: 32881.928746
# Epoch [94 / 100] average reconstruction error: 32874.863806
# Epoch [95 / 100] average reconstruction error: 32872.661068
# Epoch [96 / 100] average reconstruction error: 32876.160373
# Epoch [97 / 100] average reconstruction error: 32868.832494
# Epoch [98 / 100] average reconstruction error: 32861.226725
# Epoch [99 / 100] average reconstruction error: 32858.773587
# Epoch [100 / 100] average reconstruction error: 32858.080440

# %% [markdown]
# # Affichage de la courbe de loss

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Evaluation du score sur le Dataset de TEST

# %%
# set to evaluation mode
vae.eval()

test_loss_avg, num_batches = 0, 0
for image_batch, _ in test_dataloader:
    
    with torch.no_grad():
    
        image_batch = image_batch.to(device)

        # vae reconstruction
        image_batch_recon, latent_mu, latent_logvar = vae(image_batch)

        # reconstruction error
        loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

        test_loss_avg += loss.item()
        num_batches += 1
    
test_loss_avg /= num_batches
print('average reconstruction error: %f' % (test_loss_avg))
# Out:
# average reconstruction error: 33113.580770

# %% [markdown]
# # Reconstruction

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

# En entrée, l'image à reconstruire et le modèle utilisé pour la reconstruction



def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()

images, labels = iter(test_dataloader).next()

# Affichage de l'image originale
print('Image originale')
show_image(torchvision.utils.make_grid(images[1:50],10,5))
plt.show()

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
visualise_output(images, vae)
# Out:
# Image originale
# VAE reconstruction:

# %% [markdown]
# # Affichage de la courbe de loss

# %%
import matplotlib.pyplot as plt
plt.ion()

fig = plt.figure()
plt.plot(train_loss_avg)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# # Reconstruction

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.ion()

import torchvision.utils

vae.eval()

# En entrée, l'image à reconstruire et le modèle utilisé pour la reconstruction



def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():
    
        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = torchvision.utils.make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()

images, labels = iter(test_dataloader).next()

# Affichage de l'image originale
print('Image originale')
show_image(torchvision.utils.make_grid(images[1:50],10,5))
plt.show()

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
visualise_output(images, vae)
# Out:
# Image originale
# VAE reconstruction:

# %% [markdown]
# # Interpolation dans l'espace latent

# %%
vae.eval()

def interpolation(lambda1, model, img1, img2):
    
    with torch.no_grad():
    
        # latent vector of first image
        img1 = img1.to(device)
        latent_1, _ = model.encoder(img1)

        # latent vector of second image
        img2 = img2.to(device)
        latent_2, _ = model.encoder(img2)

        # interpolation of the two latent vectors
        inter_latent = lambda1* latent_1 + (1- lambda1) * latent_2

        # reconstruct interpolated image
        inter_image = model.decoder(inter_latent)
        inter_image = inter_image.cpu()

        return inter_image
    
# sort part of test set by digit
digits = [[] for _ in range(10)]
for img_batch, label_batch in test_dataloader:
    for i in range(img_batch.size(0)):
        digits[label_batch[i]].append(img_batch[i:i+1])
    if sum(len(d) for d in digits) >= 1000:
        break;

# interpolation lambdas
lambda_range=np.linspace(0,1,10)

fig, axs = plt.subplots(2,5, figsize=(15, 6))
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

for ind,l in enumerate(lambda_range):
    inter_image=interpolation(float(l), vae, digits[7][0], digits[1][0])
   
    inter_image = to_img(inter_image)
    
    image = inter_image.numpy()
   
    axs[ind].imshow(image[0,0,:,:], cmap='gray')
    axs[ind].set_title('lambda_val='+str(round(l,1)))
plt.show()

# %% [markdown]
# # Utilisation du VAE comme générateur
#
# Un autoencodeur variationnel peut générer de nouveaux chiffres en tirant des vecteurs latents de la distribution précédente. Les chiffres générés ne sont bien sûr pas parfaits

# %%
vae.eval()

with torch.no_grad():

    # sample latent vectors from the normal distribution
    latent = torch.randn(128, latent_dims, device=device)

    # reconstruct images from the latent vectors
    img_recon = vae.decoder(latent)
    img_recon = img_recon.cpu()

    fig, ax = plt.subplots(figsize=(5, 5))
    show_image(torchvision.utils.make_grid(img_recon.data[:100],10,5))
    plt.show()

# %% [markdown]
# # Espace latent 2D

# %%
# load a network that was trained with a 2d latent space
if latent_dims != 2:
    print('Please change the parameters to two latent dimensions.')
    
with torch.no_grad():
    
    # create a sample grid in 2d latent space
    latent_x = np.linspace(-1.5,1.5,20)
    latent_y = np.linspace(-1.5,1.5,20)
    latents = torch.FloatTensor(len(latent_y), len(latent_x), 2)
    for i, lx in enumerate(latent_x):
        for j, ly in enumerate(latent_y):
            latents[j, i, 0] = lx
            latents[j, i, 1] = ly
    latents = latents.view(-1, 2) # flatten grid into a batch

    # reconstruct images from the latent vectors
    latents = latents.to(device)
    image_recon = vae.decoder(latents)
    image_recon = image_recon.cpu()

    fig, ax = plt.subplots(figsize=(10, 10))
    show_image(torchvision.utils.make_grid(image_recon.data[:400],20,5))
    plt.show()
